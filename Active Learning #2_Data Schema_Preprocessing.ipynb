# %%
pip install wandb
# Out:
# Requirement already satisfied: wandb in /opt/conda/lib/python3.8/site-packages (0.18.5)
# Requirement already satisfied: click!=8.0.0,>=7.1 in /opt/conda/lib/python3.8/site-packages (from wandb) (8.1.7)
# Requirement already satisfied: docker-pycreds>=0.4.0 in /opt/conda/lib/python3.8/site-packages (from wandb) (0.4.0)
# Requirement already satisfied: gitpython!=3.1.29,>=1.0.0 in /opt/conda/lib/python3.8/site-packages (from wandb) (3.1.43)
# Requirement already satisfied: platformdirs in /opt/conda/lib/python3.8/site-packages (from wandb) (4.2.2)
# Requirement already satisfied: protobuf!=4.21.0,!=5.28.0,<6,>=3.12.0 in /opt/conda/lib/python3.8/site-packages (from wandb) (3.20.3)
# Requirement already satisfied: psutil>=5.0.0 in /opt/conda/lib/python3.8/site-packages (from wandb) (5.9.8)
# Requirement already satisfied: pyyaml in /opt/conda/lib/python3.8/site-packages (from wandb) (6.0.1)
# Requirement already satisfied: requests<3,>=2.0.0 in /opt/conda/lib/python3.8/site-packages (from wandb) (2.32.2)
# Requirement already satisfied: sentry-sdk>=2.0.0 in /opt/conda/lib/python3.8/site-packages (from wandb) (2.17.0)
# Requirement already satisfied: setproctitle in /opt/conda/lib/python3.8/site-packages (from wandb) (1.3.3)
# Requirement already satisfied: setuptools in /opt/conda/lib/python3.8/site-packages (from wandb) (65.6.3)
# Requirement already satisfied: typing-extensions<5,>=4.4 in /opt/conda/lib/python3.8/site-packages (from wandb) (4.7.1)
# Requirement already satisfied: six>=1.4.0 in /opt/conda/lib/python3.8/site-packages (from docker-pycreds>=0.4.0->wandb) (1.16.0)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /opt/conda/lib/python3.8/site-packages (from gitpython!=3.1.29,>=1.0.0->wandb) (4.0.11)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.8/site-packages (from requests<3,>=2.0.0->wandb) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.8/site-packages (from requests<3,>=2.0.0->wandb) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.8/site-packages (from requests<3,>=2.0.0->wandb) (1.26.20)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.8/site-packages (from requests<3,>=2.0.0->wandb) (2024.2.2)
# Requirement already satisfied: smmap<6,>=3.0.1 in /opt/conda/lib/python3.8/site-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.29,>=1.0.0->wandb) (5.0.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
import os
import time
import torch

import torchvision.transforms as transforms
import torchvision.models as models
from torch.utils.data import Dataset, DataLoader

import torch.optim as optim
import torch.nn as nn
import torch.nn.functional as F
from PIL import Image

# import wandb

### GPU Setting ###
USE_CUDA = torch.cuda.is_available()
DEVICE = torch.device("cuda:0" if USE_CUDA else "cpu")
print(DEVICE)
# Out:
# cuda:0

# %%
pip install --upgrade pip
# Out:
# Requirement already satisfied: pip in /opt/conda/lib/python3.8/site-packages (24.3.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
"""#기본 베이스 코드.

### Custom Dataset ###
class CUB2011(Dataset):
    def __init__(self, transform, mode='train'):
        self.transform = transform
        self.mode = mode
        base_path = 'datasets'  # 기본 경로 설정

        if self.mode == 'train':
            folder_path = os.path.join(base_path, 'train')
        elif self.mode == 'valid':
            folder_path = os.path.join(base_path, 'valid')
        elif self.mode == 'test':
            folder_path = os.path.join(base_path, 'test')

        # 디렉토리 제외하고 파일만 리스트에 포함
        self.image_folder = [f for f in os.listdir(folder_path) if os.path.isfile(os.path.join(folder_path, f))]

    def __len__(self):
        return len(self.image_folder)

    def __getitem__(self, idx):
        img_path = self.image_folder[idx]
        img = Image.open(os.path.join('datasets/', self.mode, img_path)).convert('RGB')
        img = self.transform(img)

        # 라벨을 이미지 파일명에서 추출 (예: 파일명이 'image_3.jpg'일 때 라벨은 3)
        label = img_path.split('_')[-1].split('.')[0]
        label = int(label)
        return img, label"""
# Out:
# "#기본 베이스 코드.\n\n### Custom Dataset ###\nclass CUB2011(Dataset):\n    def __init__(self, transform, mode='train'):\n        self.transform = transform\n        self.mode = mode\n        base_path = 'datasets'  # 기본 경로 설정\n\n        if self.mode == 'train':\n            folder_path = os.path.join(base_path, 'train')\n        elif self.mode == 'valid':\n            folder_path = os.path.join(base_path, 'valid')\n        elif self.mode == 'test':\n            folder_path = os.path.join(base_path, 'test')\n\n        # 디렉토리 제외하고 파일만 리스트에 포함\n        self.image_folder = [f for f in os.listdir(folder_path) if os.path.isfile(os.path.join(folder_path, f))]\n\n    def __len__(self):\n        return len(self.image_folder)\n\n    def __getitem__(self, idx):\n        img_path = self.image_folder[idx]\n        img = Image.open(os.path.join('datasets/', self.mode, img_path)).convert('RGB')\n        img = self.transform(img)\n\n        # 라벨을 이미지 파일명에서 추출 (예: 파일명이 'image_3.jpg'일 때 라벨은 3)\n        label = img_path.split('_')[-1].split('.')[0]\n        label = int(label)\n        return img, label"

# %%
import zipfile
import os

# 압축 파일과 압축 해제 경로
zip_file_path = 'CUB_200_2011_repackage_class50.zip'
extract_to = 'CUB_200_2011_class50'

# 폴더가 존재하지 않으면 생성
os.makedirs(extract_to, exist_ok=True)

# 압축 해제
with zipfile.ZipFile(zip_file_path, 'r') as zip_ref:
    zip_ref.extractall(extract_to)

print(f"'{zip_file_path}' 파일이 '{extract_to}' 폴더에 성공적으로 압축 해제되었습니다.")
# Out:
# 'CUB_200_2011_repackage_class50.zip' 파일이 'CUB_200_2011_class50' 폴더에 성공적으로 압축 해제되었습니다.

# %% [markdown]
# # 학습 Schema 변형, 예시 데이터 증강
# - dataset 증강

# %%
### Custom Dataset ###
class CUB2011(Dataset):
    def __init__(self, transform, mode='train'):
        self.transform = transform
        self.mode = mode
        base_path = 'datasets'  # 기본 경로 설정

        if self.mode == 'train':
            folder_path = os.path.join(base_path, 'train')
        elif self.mode == 'valid':
            folder_path = os.path.join(base_path, 'valid')
        elif self.mode == 'test':
            folder_path = os.path.join(base_path, 'test')

        # 디렉토리 제외하고 파일만 리스트에 포함
        self.image_folder = [f for f in os.listdir(folder_path) if os.path.isfile(os.path.join(folder_path, f))]

    def __len__(self):
        return len(self.image_folder)

    def __getitem__(self, idx):
        img_path = self.image_folder[idx]
        img = Image.open(os.path.join('datasets/', self.mode, img_path)).convert('RGB')
        img = self.transform(img)

        # 라벨을 이미지 파일명에서 추출 (예: 파일명이 'image_3.jpg'일 때 라벨은 3)
        label = img_path.split('_')[-1].split('.')[0]
        label = int(label)
        return img, label

# %% [markdown]
# ### Dataset 증강
# - 크기 448 by 448 고정
# - 무작위 회전
# - 무작위 크롭
# - 좌우 반전

# %%
from torch.utils.data import ConcatDataset, DataLoader
from torchvision import transforms

# 데이터 변환 정의
transforms_train = transforms.Compose([
    transforms.Resize((448, 448)),              # 크기 조정
    transforms.RandomRotation(15),              # 무작위 회전
    transforms.RandomResizedCrop(448, scale=(0.8, 1.0)),  # 무작위 크롭
    transforms.RandomHorizontalFlip(p=0.5),     # 좌우 반전
    transforms.ToTensor(),                      # 텐서 변환
])

transforms_valtest = transforms.Compose([
    transforms.Resize((448, 448)),              # 크기 조정
    transforms.ToTensor(),                      # 텐서 변환
])

# %%
from torch.utils.data import ConcatDataset, DataLoader

# 기본 Train 데이터셋
org_train_set = CUB2011(mode='train', transform=transforms_valtest)  # 기본 크기 조정만 적용

# 증강된 Train 데이터셋
transformed_train_set = CUB2011(mode='train', transform=transforms_train)

# 기본 데이터셋과 증강 데이터셋을 결합
train_set = ConcatDataset([org_train_set, transformed_train_set])

# Validation 및 Test 데이터셋
val_set = CUB2011(mode='valid', transform=transforms_valtest)
test_set = CUB2011(mode='test', transform=transforms_valtest)

# 데이터셋 크기 확인
print('Num of each dataset:', len(train_set), len(val_set), len(test_set))

print("Loaded combined dataloader")
# Out:
# Num of each dataset: 4720 296 298
# Loaded combined dataloader

# %%
#Model List 선정
"""
1. EfficientNet_V2_M_Weights.IMAGENET1K_V1
2. ResNet50_Weights.IMAGENET1K_V2 : parameter수가 2배 차이나지만, 성능은 6퍼센트 높다
3. RegNet_Y_1_6GF_Weights_IMAGENET1K_V2 : ResNet18 parameter 수와 같은데 성능이 6퍼센트 높다.
4. ConvNext_Tiny_Weights.IMAGENET1K_V1 
"""
model_names = {
    "EfficientNet_V2_M": models.efficientnet_v2_m,
    "ResNet50": models.resnet50,
    "RegNet_Y_1_6GF": models.regnet_y_1_6gf,
    "ConvNeXt_Tiny": models.convnext_tiny
}

# %%
import wandb

### Train/Evaluation with wandb logging ###
def train(model, train_loader, optimizer, epoch):
    model.train()
    for i, (image, target) in enumerate(train_loader):
        image, target = image.to(DEVICE), target.to(DEVICE)
        output = model(image)
        optimizer.zero_grad()
        train_loss = F.cross_entropy(output, target).to(DEVICE)
        train_loss.backward()
        optimizer.step()

        # 매 10번째 배치마다 로그 남기기
        if i % 10 == 0:
            print(f'Train Epoch : {epoch} [{i}/{len(train_loader)}]\tLoss: {train_loss.item(): .6f}')
            wandb.log({"train_loss": train_loss.item(), "epoch": epoch})
    return train_loss

def evaluate(model, val_loader):
    model.eval()
    eval_loss = 0
    correct = 0
    with torch.no_grad():
        for i, (image, target) in enumerate(val_loader):
            image, target = image.to(DEVICE), target.to(DEVICE)
            output = model(image)
            eval_loss += F.cross_entropy(output, target, reduction= 'sum').item()
            pred = output.argmax(1, keepdim=True)
            correct += pred.eq(target.view_as(pred)).sum().item()

    eval_loss /= len(val_loader.dataset)
    eval_accuracy = 100 * correct / len(val_loader.dataset)

    # validation 결과 wandb에 기록
    wandb.log({"val_loss": eval_loss, "val_accuracy": eval_accuracy})
    return eval_loss, eval_accuracy

# %%
# 하이퍼파라미터 스윕 설정
sweep_config = {
    'name' : 'Preprocess',
    'method': 'grid',
    'metric': {
        'name': 'val_accuracy',  # 최적화할 메트릭
        'goal': 'maximize'  # 성능을 최대화하려는 목표
    },
    'parameters': {
        'model_name': {
            'values': list(model_names.keys())
        },
        'learning_rate': {
            'values': [0.01, 0.001, 0.0001]  # 실험할 learning rate
        },
        'epochs': {
            'value': 50
        },
        'batch_size': {
            'values': [16, 32, 64]  # 실험할 배치 사이즈
        },
        'optimizer': {
            'values': ['sgd', 'rmsprop', 'adam']  # 사용할 optimizer
        }
    }
}

# Sweep 생성
sweep_id = wandb.sweep(sweep_config, project="model-comparison")
# Out:
# wandb: Using wandb-core as the SDK backend. Please refer to https://wandb.me/wandb-core for more information.
# Create sweep with ID: 0zankx6a
# Sweep URL: https://wandb.ai/empe8339-gachon-university/model-comparison/sweeps/0zankx6a

# %%
# 학습 및 평가 함수
def train_and_evaluate(config=None):
    # wandb config 설정
    with wandb.init(config=config):
        config = wandb.config

        # 모델 로드
        print(f"")
        model_func = model_names[config.model_name]
        model = model_func(pretrained=True)
        
        # Transfer learning: 마지막 레이어 수정
        if hasattr(model, 'fc'):
            num_features = model.fc.in_features
            model.fc = nn.Linear(num_features, 50)
        else:
            num_features = model.classifier[1].in_features
            model.classifier[1] = nn.Linear(num_features, 50)

        # 모델 파라미터 설정
        params_to_update = []
        for param_name, param in model.named_parameters():
            if 'fc' in param_name or 'classifier.1' in param_name:
                param.requires_grad = True
                params_to_update.append(param)
            else:
                param.requires_grad = False

        model.to(DEVICE)
        
        if Preprocessing is True :
            train_loader = DataLoader(train_set, batch_size=config.batch_size, shuffle=True)
        else :
            train_loader = DataLoader(org_train_set, batch_size=config.batch_size, shuffle=True)

        val_loader = DataLoader(val_set, batch_size=config.batch_size, shuffle=False)
        test_loader = DataLoader(test_set, batch_size=config.batch_size, shuffle=False)

        # 옵티마이저 정의
        if config.optimizer == 'adam':
            optimizer = optim.Adam(params_to_update, lr=config.learning_rate)
        elif config.optimizer == 'sgd':
            optimizer = optim.SGD(params_to_update, lr=config.learning_rate)
        elif config.optimizer == 'rmsprop':
            optimizer = optim.RMSprop(params_to_update, lr=config.learning_rate)
        
        best_val_accuracy = 0
        for epoch in range(config.epochs):
            train_loss = train(model, train_loader, optimizer, epoch)
            val_loss, val_accuracy = evaluate(model, val_loader)

            # 최고 성능 모델 저장
            if val_accuracy > best_val_accuracy:
                best_val_accuracy = val_accuracy
                torch.save(model.state_dict(), f"./best_model_{config.model_name}.pth")
                print(f'Best model saved for {config.model_name} with accuracy: {best_val_accuracy:.4f}')

            # Log epoch results
            wandb.log({"best_val_accuracy": best_val_accuracy, "val_loss": val_loss, "epoch": epoch})

        # 최종 테스트 평가
        test_loss, test_accuracy = evaluate(model, test_loader)
        print(f'[FINAL] {config.model_name} Test Loss: {test_loss:.4f}, Accuracy: {test_accuracy:.4f}')
        wandb.log({"test_loss": test_loss, "test_accuracy": test_accuracy})

# %%
# Sweep agent 실행
Preprocessing = True
wandb.agent(sweep_id, train_and_evaluate)
# Out:
# wandb: Agent Starting Run: n2h8sz9b with config:
# wandb: 	batch_size: 16
# wandb: 	epochs: 50
# wandb: 	learning_rate: 0.01
# wandb: 	model_name: EfficientNet_V2_M
# wandb: 	optimizer: sgd
# wandb: Currently logged in as: empe8339 (empe8339-gachon-university). Use `wandb login --relogin` to force relogin
# Tracking run with wandb version 0.18.5
# Run data is saved locally in <code>/home/jovyan/wandb/run-20241029_131531-n2h8sz9b</code>
# Syncing run <strong><a href='https://wandb.ai/empe8339-gachon-university/model-comparison/runs/n2h8sz9b' target="_blank">resilient-sweep-1</a></strong> to <a href='https://wandb.ai/empe8339-gachon-university/model-comparison' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>Sweep page: <a href='https://wandb.ai/empe8339-gachon-university/model-comparison/sweeps/0zankx6a' target="_blank">https://wandb.ai/empe8339-gachon-university/model-comparison/sweeps/0zankx6a</a>
#  View project at <a href='https://wandb.ai/empe8339-gachon-university/model-comparison' target="_blank">https://wandb.ai/empe8339-gachon-university/model-comparison</a>
#  View sweep at <a href='https://wandb.ai/empe8339-gachon-university/model-comparison/sweeps/0zankx6a' target="_blank">https://wandb.ai/empe8339-gachon-university/model-comparison/sweeps/0zankx6a</a>
#  View run at <a href='https://wandb.ai/empe8339-gachon-university/model-comparison/runs/n2h8sz9b' target="_blank">https://wandb.ai/empe8339-gachon-university/model-comparison/runs/n2h8sz9b</a>
# /opt/conda/lib/python3.8/site-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /opt/conda/lib/python3.8/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=EfficientNet_V2_M_Weights.IMAGENET1K_V1`. You can also use `weights=EfficientNet_V2_M_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Train Epoch : 0 [0/295]	Loss:  3.898070
# Train Epoch : 0 [10/295]	Loss:  3.912349
# Train Epoch : 0 [20/295]	Loss:  3.910599
# Train Epoch : 0 [30/295]	Loss:  3.864437
# Train Epoch : 0 [40/295]	Loss:  3.743381
# Train Epoch : 0 [50/295]	Loss:  3.742923
# Train Epoch : 0 [60/295]	Loss:  3.554988
# Train Epoch : 0 [70/295]	Loss:  3.573732
# Train Epoch : 0 [80/295]	Loss:  3.578841
# Train Epoch : 0 [90/295]	Loss:  3.403654
# Train Epoch : 0 [100/295]	Loss:  3.537813
# Train Epoch : 0 [110/295]	Loss:  3.289495
# Train Epoch : 0 [120/295]	Loss:  3.329630
# Train Epoch : 0 [130/295]	Loss:  3.270592
# Train Epoch : 0 [140/295]	Loss:  3.188569
# Train Epoch : 0 [150/295]	Loss:  3.106160
# Train Epoch : 0 [160/295]	Loss:  3.203964
# Train Epoch : 0 [170/295]	Loss:  3.165785
# Train Epoch : 0 [180/295]	Loss:  2.892609
# Train Epoch : 0 [190/295]	Loss:  2.870606
# Train Epoch : 0 [200/295]	Loss:  2.667094
# Train Epoch : 0 [210/295]	Loss:  2.864072
# Train Epoch : 0 [220/295]	Loss:  2.838210
# Train Epoch : 0 [230/295]	Loss:  2.587713
# Train Epoch : 0 [240/295]	Loss:  2.336585
# Train Epoch : 0 [250/295]	Loss:  2.324574
# Train Epoch : 0 [260/295]	Loss:  2.077671
# Train Epoch : 0 [270/295]	Loss:  2.162939
# Train Epoch : 0 [280/295]	Loss:  1.945246
# Train Epoch : 0 [290/295]	Loss:  1.866538
# Best model saved for EfficientNet_V2_M with accuracy: 74.3243
# Train Epoch : 1 [0/295]	Loss:  2.232090
# Train Epoch : 1 [10/295]	Loss:  1.909128
# Train Epoch : 1 [20/295]	Loss:  1.438851
# Train Epoch : 1 [30/295]	Loss:  1.908244
# Train Epoch : 1 [40/295]	Loss:  1.355445
# Train Epoch : 1 [50/295]	Loss:  1.380176
# Train Epoch : 1 [60/295]	Loss:  1.803144
# Train Epoch : 1 [70/295]	Loss:  1.003019
# Train Epoch : 1 [80/295]	Loss:  1.506095
# Train Epoch : 1 [90/295]	Loss:  1.857132
# Train Epoch : 1 [100/295]	Loss:  1.123422
# Train Epoch : 1 [110/295]	Loss:  1.646385
# Train Epoch : 1 [120/295]	Loss:  1.639360
# Train Epoch : 1 [130/295]	Loss:  1.208079
# Train Epoch : 1 [140/295]	Loss:  1.121204
# Train Epoch : 1 [150/295]	Loss:  1.319804
# Train Epoch : 1 [160/295]	Loss:  0.992747
# Train Epoch : 1 [170/295]	Loss:  1.451873
# Train Epoch : 1 [180/295]	Loss:  1.246579
# Train Epoch : 1 [190/295]	Loss:  0.947394
# Train Epoch : 1 [200/295]	Loss:  0.778047
# Train Epoch : 1 [210/295]	Loss:  1.195519
# Train Epoch : 1 [220/295]	Loss:  0.697477
# Train Epoch : 1 [230/295]	Loss:  1.191696
# Train Epoch : 1 [240/295]	Loss:  0.845825
# Train Epoch : 1 [250/295]	Loss:  1.002869
# Train Epoch : 1 [260/295]	Loss:  1.114637
# Train Epoch : 1 [270/295]	Loss:  1.007713
# Train Epoch : 1 [280/295]	Loss:  0.953322
# Train Epoch : 1 [290/295]	Loss:  1.143331
# Best model saved for EfficientNet_V2_M with accuracy: 86.8243
# Train Epoch : 2 [0/295]	Loss:  0.848671
# Train Epoch : 2 [10/295]	Loss:  0.739674
# Train Epoch : 2 [20/295]	Loss:  0.617534
# Train Epoch : 2 [30/295]	Loss:  0.484212
# Train Epoch : 2 [40/295]	Loss:  0.592752
# Train Epoch : 2 [50/295]	Loss:  0.504720
# Train Epoch : 2 [60/295]	Loss:  1.098009
# Train Epoch : 2 [70/295]	Loss:  0.533573
# Train Epoch : 2 [80/295]	Loss:  0.537345
# Train Epoch : 2 [90/295]	Loss:  0.420201
# Train Epoch : 2 [100/295]	Loss:  0.404583
# Train Epoch : 2 [110/295]	Loss:  0.643902
# Train Epoch : 2 [120/295]	Loss:  0.533035
# Train Epoch : 2 [130/295]	Loss:  0.559745
# Train Epoch : 2 [140/295]	Loss:  0.460974
# Train Epoch : 2 [150/295]	Loss:  0.557669
# Train Epoch : 2 [160/295]	Loss:  0.576289
# Train Epoch : 2 [170/295]	Loss:  0.805811
# Train Epoch : 2 [180/295]	Loss:  0.617957
# Train Epoch : 2 [190/295]	Loss:  0.643811
# Train Epoch : 2 [200/295]	Loss:  0.945991
# Train Epoch : 2 [210/295]	Loss:  0.738118
# Train Epoch : 2 [220/295]	Loss:  0.552446
# Train Epoch : 2 [230/295]	Loss:  0.536383
# Train Epoch : 2 [240/295]	Loss:  0.302247
# Train Epoch : 2 [250/295]	Loss:  0.641816
# Train Epoch : 2 [260/295]	Loss:  0.443318
# Train Epoch : 2 [270/295]	Loss:  0.560718
# Train Epoch : 2 [280/295]	Loss:  0.558104
# Train Epoch : 2 [290/295]	Loss:  0.758076
# Best model saved for EfficientNet_V2_M with accuracy: 90.5405
# Train Epoch : 3 [0/295]	Loss:  0.280080
# Train Epoch : 3 [10/295]	Loss:  0.893439
# Train Epoch : 3 [20/295]	Loss:  0.453973
# Train Epoch : 3 [30/295]	Loss:  0.550607
# Train Epoch : 3 [40/295]	Loss:  0.404642
# Train Epoch : 3 [50/295]	Loss:  0.857150
# Train Epoch : 3 [60/295]	Loss:  0.474277
# Train Epoch : 3 [70/295]	Loss:  0.526186
# Train Epoch : 3 [80/295]	Loss:  0.502504
# Train Epoch : 3 [90/295]	Loss:  0.601172
# Train Epoch : 3 [100/295]	Loss:  0.401233
# Train Epoch : 3 [110/295]	Loss:  0.571628
# Train Epoch : 3 [120/295]	Loss:  0.419814
# Train Epoch : 3 [130/295]	Loss:  0.555982
# Train Epoch : 3 [140/295]	Loss:  0.382437
# Train Epoch : 3 [150/295]	Loss:  0.577127
# Train Epoch : 3 [160/295]	Loss:  0.627704
# Train Epoch : 3 [170/295]	Loss:  0.558978
# Train Epoch : 3 [180/295]	Loss:  0.282306
# Train Epoch : 3 [190/295]	Loss:  0.387072
# Train Epoch : 3 [200/295]	Loss:  0.523287
# Train Epoch : 3 [210/295]	Loss:  0.422892
# Train Epoch : 3 [220/295]	Loss:  0.676816
# Train Epoch : 3 [230/295]	Loss:  0.543887
# Train Epoch : 3 [240/295]	Loss:  0.495066
# Train Epoch : 3 [250/295]	Loss:  0.283618
# Train Epoch : 3 [260/295]	Loss:  0.472472
# Train Epoch : 3 [270/295]	Loss:  0.231861
# Train Epoch : 3 [280/295]	Loss:  0.418207
# Train Epoch : 3 [290/295]	Loss:  0.688556
# Best model saved for EfficientNet_V2_M with accuracy: 93.2432
# Train Epoch : 4 [0/295]	Loss:  0.317582
# Train Epoch : 4 [10/295]	Loss:  0.141101
# Train Epoch : 4 [20/295]	Loss:  0.385148
# Train Epoch : 4 [30/295]	Loss:  0.547389
# Train Epoch : 4 [40/295]	Loss:  0.229993
# Train Epoch : 4 [50/295]	Loss:  0.329171
# Train Epoch : 4 [60/295]	Loss:  0.910854
# Train Epoch : 4 [70/295]	Loss:  0.410851
# Train Epoch : 4 [80/295]	Loss:  0.455922
# Train Epoch : 4 [90/295]	Loss:  0.267209
# Train Epoch : 4 [100/295]	Loss:  0.275890
# Train Epoch : 4 [110/295]	Loss:  0.570021
# Train Epoch : 4 [120/295]	Loss:  0.426868
# Train Epoch : 4 [130/295]	Loss:  0.457419
# Train Epoch : 4 [140/295]	Loss:  1.006445
# Train Epoch : 4 [150/295]	Loss:  0.268624
# Train Epoch : 4 [160/295]	Loss:  0.218974
# Train Epoch : 4 [170/295]	Loss:  0.503666
# Train Epoch : 4 [180/295]	Loss:  0.909461
# Train Epoch : 4 [190/295]	Loss:  0.368712
# Train Epoch : 4 [200/295]	Loss:  0.579990
# Train Epoch : 4 [210/295]	Loss:  0.499050
# Train Epoch : 4 [220/295]	Loss:  0.335140
# Train Epoch : 4 [230/295]	Loss:  0.281663
# Train Epoch : 4 [240/295]	Loss:  0.325884
# Train Epoch : 4 [250/295]	Loss:  0.196054
# Train Epoch : 4 [260/295]	Loss:  0.483633
# Train Epoch : 4 [270/295]	Loss:  0.293752
# Train Epoch : 4 [280/295]	Loss:  0.285625
# Train Epoch : 4 [290/295]	Loss:  0.313521
# Best model saved for EfficientNet_V2_M with accuracy: 94.9324
# Train Epoch : 5 [0/295]	Loss:  0.214158
# Train Epoch : 5 [10/295]	Loss:  0.485083
# Train Epoch : 5 [20/295]	Loss:  0.315849
# Train Epoch : 5 [30/295]	Loss:  0.400661
# Train Epoch : 5 [40/295]	Loss:  0.124341
# Train Epoch : 5 [50/295]	Loss:  0.101041
# Train Epoch : 5 [60/295]	Loss:  0.159896
# Train Epoch : 5 [70/295]	Loss:  0.115223
# Train Epoch : 5 [80/295]	Loss:  0.262688
# Train Epoch : 5 [90/295]	Loss:  0.302237
# Train Epoch : 5 [100/295]	Loss:  0.362759
# Train Epoch : 5 [110/295]	Loss:  0.354115
# Train Epoch : 5 [120/295]	Loss:  0.363507
# Train Epoch : 5 [130/295]	Loss:  0.224363
# Train Epoch : 5 [140/295]	Loss:  0.192881
# Train Epoch : 5 [150/295]	Loss:  0.218029
# Train Epoch : 5 [160/295]	Loss:  0.741401
# Train Epoch : 5 [170/295]	Loss:  0.308132
# Train Epoch : 5 [180/295]	Loss:  0.411435
# Train Epoch : 5 [190/295]	Loss:  0.184286
# Train Epoch : 5 [200/295]	Loss:  0.869862
# Train Epoch : 5 [210/295]	Loss:  0.381352
# Train Epoch : 5 [220/295]	Loss:  0.338516
# Train Epoch : 5 [230/295]	Loss:  0.225975
# Train Epoch : 5 [240/295]	Loss:  0.435342
# Train Epoch : 5 [250/295]	Loss:  0.452029
# Train Epoch : 5 [260/295]	Loss:  0.652392
# Train Epoch : 5 [270/295]	Loss:  0.479211
# Train Epoch : 5 [280/295]	Loss:  0.426265
# Train Epoch : 5 [290/295]	Loss:  0.265648
# Best model saved for EfficientNet_V2_M with accuracy: 95.2703
# Train Epoch : 6 [0/295]	Loss:  0.197269
# Train Epoch : 6 [10/295]	Loss:  0.351244
# Train Epoch : 6 [20/295]	Loss:  0.241867
# Train Epoch : 6 [30/295]	Loss:  0.342370
# Train Epoch : 6 [40/295]	Loss:  0.321798
# Train Epoch : 6 [50/295]	Loss:  0.193745
# Train Epoch : 6 [60/295]	Loss:  0.326365
# Train Epoch : 6 [70/295]	Loss:  0.184191
# Train Epoch : 6 [80/295]	Loss:  0.169401
# Train Epoch : 6 [90/295]	Loss:  0.479062
# Train Epoch : 6 [100/295]	Loss:  0.352778
# Train Epoch : 6 [110/295]	Loss:  0.712397
# Train Epoch : 6 [120/295]	Loss:  0.203886
# Train Epoch : 6 [130/295]	Loss:  0.270333
# Train Epoch : 6 [140/295]	Loss:  0.255337
# Train Epoch : 6 [150/295]	Loss:  0.147442
# Train Epoch : 6 [160/295]	Loss:  0.112579
# Train Epoch : 6 [170/295]	Loss:  0.144337
# Train Epoch : 6 [180/295]	Loss:  0.250758
# Train Epoch : 6 [190/295]	Loss:  0.167001
# Train Epoch : 6 [200/295]	Loss:  0.237003
# Train Epoch : 6 [210/295]	Loss:  0.322648
# Train Epoch : 6 [220/295]	Loss:  0.462086
# Train Epoch : 6 [230/295]	Loss:  0.406065
# Train Epoch : 6 [240/295]	Loss:  0.353560
# Train Epoch : 6 [250/295]	Loss:  0.180708
# Train Epoch : 6 [260/295]	Loss:  0.286677
# Train Epoch : 6 [270/295]	Loss:  0.226387
# Train Epoch : 6 [280/295]	Loss:  0.075951
# Train Epoch : 6 [290/295]	Loss:  0.240672
# Best model saved for EfficientNet_V2_M with accuracy: 95.6081
# Train Epoch : 7 [0/295]	Loss:  0.249216
# Train Epoch : 7 [10/295]	Loss:  0.559156
# Train Epoch : 7 [20/295]	Loss:  0.176687
# Train Epoch : 7 [30/295]	Loss:  0.487610
# Train Epoch : 7 [40/295]	Loss:  0.216344
# Train Epoch : 7 [50/295]	Loss:  0.044208
# Train Epoch : 7 [60/295]	Loss:  0.460620
# Train Epoch : 7 [70/295]	Loss:  0.101699
# Train Epoch : 7 [80/295]	Loss:  0.277633
# Train Epoch : 7 [90/295]	Loss:  0.157874
# Train Epoch : 7 [100/295]	Loss:  0.167067
# Train Epoch : 7 [110/295]	Loss:  0.218022
# Train Epoch : 7 [120/295]	Loss:  0.226386
# Train Epoch : 7 [130/295]	Loss:  0.113885
# Train Epoch : 7 [140/295]	Loss:  0.167507
# Train Epoch : 7 [150/295]	Loss:  0.422365
# Train Epoch : 7 [160/295]	Loss:  0.401267
# Train Epoch : 7 [170/295]	Loss:  0.212131
# Train Epoch : 7 [180/295]	Loss:  0.231929
# Train Epoch : 7 [190/295]	Loss:  0.126541
# Train Epoch : 7 [200/295]	Loss:  0.116777
# Train Epoch : 7 [210/295]	Loss:  0.203768
# Train Epoch : 7 [220/295]	Loss:  0.174990
# Train Epoch : 7 [230/295]	Loss:  0.370183
# Train Epoch : 7 [240/295]	Loss:  0.246115
# Train Epoch : 7 [250/295]	Loss:  0.128706
# Train Epoch : 7 [260/295]	Loss:  0.329009
# Train Epoch : 7 [270/295]	Loss:  0.121392
# Train Epoch : 7 [280/295]	Loss:  0.143188
# Train Epoch : 7 [290/295]	Loss:  0.137055
# Train Epoch : 8 [0/295]	Loss:  0.315656
# Train Epoch : 8 [10/295]	Loss:  0.176841
# Train Epoch : 8 [20/295]	Loss:  0.766567
# Train Epoch : 8 [30/295]	Loss:  0.165697
# Train Epoch : 8 [40/295]	Loss:  0.153961
# Train Epoch : 8 [50/295]	Loss:  0.350544
# Train Epoch : 8 [60/295]	Loss:  0.329444
# Train Epoch : 8 [70/295]	Loss:  0.174557
# Train Epoch : 8 [80/295]	Loss:  0.283214
# Train Epoch : 8 [90/295]	Loss:  0.157739
# Train Epoch : 8 [100/295]	Loss:  0.074871
# Train Epoch : 8 [110/295]	Loss:  0.274942
# Train Epoch : 8 [120/295]	Loss:  0.195847
# Train Epoch : 8 [130/295]	Loss:  0.285203
# Train Epoch : 8 [140/295]	Loss:  0.182434
# Train Epoch : 8 [150/295]	Loss:  0.130128
# Train Epoch : 8 [160/295]	Loss:  0.402629
# Train Epoch : 8 [170/295]	Loss:  0.167574
# Train Epoch : 8 [180/295]	Loss:  0.182592
# Train Epoch : 8 [190/295]	Loss:  0.104203
# Train Epoch : 8 [200/295]	Loss:  0.175222
# Train Epoch : 8 [210/295]	Loss:  0.129208
# Train Epoch : 8 [220/295]	Loss:  0.214739
# Train Epoch : 8 [230/295]	Loss:  0.088203
# Train Epoch : 8 [240/295]	Loss:  0.137805
# Train Epoch : 8 [250/295]	Loss:  0.090760
# Train Epoch : 8 [260/295]	Loss:  0.155375
# Train Epoch : 8 [270/295]	Loss:  0.109266
# Train Epoch : 8 [280/295]	Loss:  0.195719
# Train Epoch : 8 [290/295]	Loss:  0.329385
# Best model saved for EfficientNet_V2_M with accuracy: 96.2838
# Train Epoch : 9 [0/295]	Loss:  0.097936
# Train Epoch : 9 [10/295]	Loss:  0.098315
# Train Epoch : 9 [20/295]	Loss:  0.228439
# Train Epoch : 9 [30/295]	Loss:  0.080608
# Train Epoch : 9 [40/295]	Loss:  0.244611
# Train Epoch : 9 [50/295]	Loss:  0.215923
# Train Epoch : 9 [60/295]	Loss:  0.181175
# Train Epoch : 9 [70/295]	Loss:  0.199367
# Train Epoch : 9 [80/295]	Loss:  0.165663
# Train Epoch : 9 [90/295]	Loss:  0.108008
# Train Epoch : 9 [100/295]	Loss:  0.091954
# Train Epoch : 9 [110/295]	Loss:  0.082771
# Train Epoch : 9 [120/295]	Loss:  0.114397
# Train Epoch : 9 [130/295]	Loss:  0.165777
# Train Epoch : 9 [140/295]	Loss:  0.192130
# Train Epoch : 9 [150/295]	Loss:  0.223573
# Train Epoch : 9 [160/295]	Loss:  0.261827
# Train Epoch : 9 [170/295]	Loss:  0.187855
# Train Epoch : 9 [180/295]	Loss:  0.096658
# Train Epoch : 9 [190/295]	Loss:  0.159020
# Train Epoch : 9 [200/295]	Loss:  0.215930
# Train Epoch : 9 [210/295]	Loss:  0.223368
# Train Epoch : 9 [220/295]	Loss:  0.267041
# Train Epoch : 9 [230/295]	Loss:  0.065966
# Train Epoch : 9 [240/295]	Loss:  0.302381
# Train Epoch : 9 [250/295]	Loss:  0.132262
# Train Epoch : 9 [260/295]	Loss:  0.231231
# Train Epoch : 9 [270/295]	Loss:  0.138774
# Train Epoch : 9 [280/295]	Loss:  0.257590
# Train Epoch : 9 [290/295]	Loss:  0.267104
# Train Epoch : 10 [0/295]	Loss:  0.158779
# Train Epoch : 10 [10/295]	Loss:  0.069360
# Train Epoch : 10 [20/295]	Loss:  0.111042
# Train Epoch : 10 [30/295]	Loss:  0.219201
# Train Epoch : 10 [40/295]	Loss:  0.024275
# Train Epoch : 10 [50/295]	Loss:  0.053545
# Train Epoch : 10 [60/295]	Loss:  0.280828
# Train Epoch : 10 [70/295]	Loss:  0.156140
# Train Epoch : 10 [80/295]	Loss:  0.172192
# Train Epoch : 10 [90/295]	Loss:  0.093956
# Train Epoch : 10 [100/295]	Loss:  0.223672
# Train Epoch : 10 [110/295]	Loss:  0.354735
# Train Epoch : 10 [120/295]	Loss:  0.172150
# Train Epoch : 10 [130/295]	Loss:  0.183092
# Train Epoch : 10 [140/295]	Loss:  0.183510
# Train Epoch : 10 [150/295]	Loss:  0.194209
# Train Epoch : 10 [160/295]	Loss:  0.298503
# Train Epoch : 10 [170/295]	Loss:  0.315071
# Train Epoch : 10 [180/295]	Loss:  0.226922
# Train Epoch : 10 [190/295]	Loss:  0.235515
# Train Epoch : 10 [200/295]	Loss:  0.164035
# Train Epoch : 10 [210/295]	Loss:  0.775968
# Train Epoch : 10 [220/295]	Loss:  0.125638
# Train Epoch : 10 [230/295]	Loss:  0.452899
# Train Epoch : 10 [240/295]	Loss:  0.174621
# Train Epoch : 10 [250/295]	Loss:  0.099298
# Train Epoch : 10 [260/295]	Loss:  0.151652
# Train Epoch : 10 [270/295]	Loss:  0.257677
# Train Epoch : 10 [280/295]	Loss:  0.033190
# Train Epoch : 10 [290/295]	Loss:  0.146808
# Train Epoch : 11 [0/295]	Loss:  0.185168
# Train Epoch : 11 [10/295]	Loss:  0.118096
# Train Epoch : 11 [20/295]	Loss:  0.240589
# Train Epoch : 11 [30/295]	Loss:  0.143242
# Train Epoch : 11 [40/295]	Loss:  0.585100
# Train Epoch : 11 [50/295]	Loss:  0.123982
# Train Epoch : 11 [60/295]	Loss:  0.033651
# Train Epoch : 11 [70/295]	Loss:  0.142389
# Train Epoch : 11 [80/295]	Loss:  0.077380
# Train Epoch : 11 [90/295]	Loss:  0.073328
# Train Epoch : 11 [100/295]	Loss:  0.161454
# Train Epoch : 11 [110/295]	Loss:  0.734847
# Train Epoch : 11 [120/295]	Loss:  0.078825
# Train Epoch : 11 [130/295]	Loss:  0.051397
# Train Epoch : 11 [140/295]	Loss:  0.139508
# Train Epoch : 11 [150/295]	Loss:  0.194812
# Train Epoch : 11 [160/295]	Loss:  0.255176
# Train Epoch : 11 [170/295]	Loss:  0.110336
# Train Epoch : 11 [180/295]	Loss:  0.231211
# Train Epoch : 11 [190/295]	Loss:  0.190600
# Train Epoch : 11 [200/295]	Loss:  0.442842
# Train Epoch : 11 [210/295]	Loss:  0.269156
# Train Epoch : 11 [220/295]	Loss:  0.093839
# Train Epoch : 11 [230/295]	Loss:  0.106571
# Train Epoch : 11 [240/295]	Loss:  0.091789
# Train Epoch : 11 [250/295]	Loss:  0.155398
# Train Epoch : 11 [260/295]	Loss:  0.135133
# Train Epoch : 11 [270/295]	Loss:  0.034586
# Train Epoch : 11 [280/295]	Loss:  0.107833
# Train Epoch : 11 [290/295]	Loss:  0.069151
# Train Epoch : 12 [0/295]	Loss:  0.101774
# Train Epoch : 12 [10/295]	Loss:  0.394865
# Train Epoch : 12 [20/295]	Loss:  0.073294
# Train Epoch : 12 [30/295]	Loss:  0.064826
# Train Epoch : 12 [40/295]	Loss:  0.248710
# Train Epoch : 12 [50/295]	Loss:  0.205837
# Train Epoch : 12 [60/295]	Loss:  0.144073
# Train Epoch : 12 [70/295]	Loss:  0.271203
# Train Epoch : 12 [80/295]	Loss:  0.078362
# Train Epoch : 12 [90/295]	Loss:  0.110610
# Train Epoch : 12 [100/295]	Loss:  0.151210
# Train Epoch : 12 [110/295]	Loss:  0.143724
# Train Epoch : 12 [120/295]	Loss:  0.050534
# Train Epoch : 12 [130/295]	Loss:  0.061612
# Train Epoch : 12 [140/295]	Loss:  0.360668
# Train Epoch : 12 [150/295]	Loss:  0.180897
# Train Epoch : 12 [160/295]	Loss:  0.100263
# Train Epoch : 12 [170/295]	Loss:  0.238617
# Train Epoch : 12 [180/295]	Loss:  0.177140
# Train Epoch : 12 [190/295]	Loss:  0.117569
# Train Epoch : 12 [200/295]	Loss:  0.345698
# Train Epoch : 12 [210/295]	Loss:  0.071875
# Train Epoch : 12 [220/295]	Loss:  0.108819
# Train Epoch : 12 [230/295]	Loss:  0.157959
# Train Epoch : 12 [240/295]	Loss:  0.082631
# Train Epoch : 12 [250/295]	Loss:  0.335403
# Train Epoch : 12 [260/295]	Loss:  0.244281
# Train Epoch : 12 [270/295]	Loss:  0.178681
# Train Epoch : 12 [280/295]	Loss:  0.205563
# Train Epoch : 12 [290/295]	Loss:  0.052293
# Train Epoch : 13 [0/295]	Loss:  0.032145
# Train Epoch : 13 [10/295]	Loss:  0.055488
# Train Epoch : 13 [20/295]	Loss:  0.065275
# Train Epoch : 13 [30/295]	Loss:  0.068621
# Train Epoch : 13 [40/295]	Loss:  0.039397
# Train Epoch : 13 [50/295]	Loss:  0.168680
# Train Epoch : 13 [60/295]	Loss:  0.119559
# Train Epoch : 13 [70/295]	Loss:  0.069854
# Train Epoch : 13 [80/295]	Loss:  0.169936
# Train Epoch : 13 [90/295]	Loss:  0.135527
# Train Epoch : 13 [100/295]	Loss:  0.083329
# Train Epoch : 13 [110/295]	Loss:  0.218340
# Train Epoch : 13 [120/295]	Loss:  0.250397
# Train Epoch : 13 [130/295]	Loss:  0.110241
# Train Epoch : 13 [140/295]	Loss:  0.063595
# Train Epoch : 13 [150/295]	Loss:  0.040823
# Train Epoch : 13 [160/295]	Loss:  0.056066
# Train Epoch : 13 [170/295]	Loss:  0.249084
# Train Epoch : 13 [180/295]	Loss:  0.225946
# Train Epoch : 13 [190/295]	Loss:  0.039483
# Train Epoch : 13 [200/295]	Loss:  0.118093
# Train Epoch : 13 [210/295]	Loss:  0.096343
# Train Epoch : 13 [220/295]	Loss:  0.086987
# Train Epoch : 13 [230/295]	Loss:  0.168797
# Train Epoch : 13 [240/295]	Loss:  0.165804
# Train Epoch : 13 [250/295]	Loss:  0.118447
# Train Epoch : 13 [260/295]	Loss:  0.174193
# Train Epoch : 13 [270/295]	Loss:  0.240401
# Train Epoch : 13 [280/295]	Loss:  0.175575
# Train Epoch : 13 [290/295]	Loss:  0.080409
# Train Epoch : 14 [0/295]	Loss:  0.082264
# Train Epoch : 14 [10/295]	Loss:  0.220834
# Train Epoch : 14 [20/295]	Loss:  0.073943
# Train Epoch : 14 [30/295]	Loss:  0.314419
# Train Epoch : 14 [40/295]	Loss:  0.144149
# Train Epoch : 14 [50/295]	Loss:  0.231355
# Train Epoch : 14 [60/295]	Loss:  0.095238
# Train Epoch : 14 [70/295]	Loss:  0.026892
# Train Epoch : 14 [80/295]	Loss:  0.066581
# Train Epoch : 14 [90/295]	Loss:  0.133196
# Train Epoch : 14 [100/295]	Loss:  0.054403
# Train Epoch : 14 [110/295]	Loss:  0.108597
# Train Epoch : 14 [120/295]	Loss:  0.145130
# Train Epoch : 14 [130/295]	Loss:  0.293167
# Train Epoch : 14 [140/295]	Loss:  0.108314
# Train Epoch : 14 [150/295]	Loss:  0.109144
# Train Epoch : 14 [160/295]	Loss:  0.033491
# Train Epoch : 14 [170/295]	Loss:  0.059602
# Train Epoch : 14 [180/295]	Loss:  0.082010
# Train Epoch : 14 [190/295]	Loss:  0.097704
# Train Epoch : 14 [200/295]	Loss:  0.092555
# Train Epoch : 14 [210/295]	Loss:  0.109955
# Train Epoch : 14 [220/295]	Loss:  0.408933
# Train Epoch : 14 [230/295]	Loss:  0.139723
# Train Epoch : 14 [240/295]	Loss:  0.129510
# Train Epoch : 14 [250/295]	Loss:  0.136893
# Train Epoch : 14 [260/295]	Loss:  0.086153
# Train Epoch : 14 [270/295]	Loss:  0.043725
# Train Epoch : 14 [280/295]	Loss:  0.106996
# Train Epoch : 14 [290/295]	Loss:  0.137646
# Train Epoch : 15 [0/295]	Loss:  0.069209
# Train Epoch : 15 [10/295]	Loss:  0.057664
# Train Epoch : 15 [20/295]	Loss:  0.084644
# Train Epoch : 15 [30/295]	Loss:  0.429437
# Train Epoch : 15 [40/295]	Loss:  0.108987
# Train Epoch : 15 [50/295]	Loss:  0.223321
# Train Epoch : 15 [60/295]	Loss:  0.040978
# Train Epoch : 15 [70/295]	Loss:  0.078429
# Train Epoch : 15 [80/295]	Loss:  0.108859
# Train Epoch : 15 [90/295]	Loss:  0.256655
# Train Epoch : 15 [100/295]	Loss:  0.172817
# Train Epoch : 15 [110/295]	Loss:  0.159703
# Train Epoch : 15 [120/295]	Loss:  0.142815
# Train Epoch : 15 [130/295]	Loss:  0.133535
# Train Epoch : 15 [140/295]	Loss:  0.012213
# Train Epoch : 15 [150/295]	Loss:  0.085254
# Train Epoch : 15 [160/295]	Loss:  0.147485
# Train Epoch : 15 [170/295]	Loss:  0.151988
# Train Epoch : 15 [180/295]	Loss:  0.179509
# Train Epoch : 15 [190/295]	Loss:  0.027094
# Train Epoch : 15 [200/295]	Loss:  0.093700
# Train Epoch : 15 [210/295]	Loss:  0.162021
# Train Epoch : 15 [220/295]	Loss:  0.028915
# Train Epoch : 15 [230/295]	Loss:  0.116897
# Train Epoch : 15 [240/295]	Loss:  0.054081
# Train Epoch : 15 [250/295]	Loss:  0.197730
# Train Epoch : 15 [260/295]	Loss:  0.152324
# Train Epoch : 15 [270/295]	Loss:  0.165003
# Train Epoch : 15 [280/295]	Loss:  0.101589
# Train Epoch : 15 [290/295]	Loss:  0.280696
# Train Epoch : 16 [0/295]	Loss:  0.075702
# Train Epoch : 16 [10/295]	Loss:  0.077095
# Train Epoch : 16 [20/295]	Loss:  0.058970
# Train Epoch : 16 [30/295]	Loss:  0.208770
# Train Epoch : 16 [40/295]	Loss:  0.241854
# Train Epoch : 16 [50/295]	Loss:  0.469864
# Train Epoch : 16 [60/295]	Loss:  0.102885
# Train Epoch : 16 [70/295]	Loss:  0.247083
# Train Epoch : 16 [80/295]	Loss:  0.261409
# Train Epoch : 16 [90/295]	Loss:  0.187891
# Train Epoch : 16 [100/295]	Loss:  0.095468
# Train Epoch : 16 [110/295]	Loss:  0.117754
# Train Epoch : 16 [120/295]	Loss:  0.194052
# Train Epoch : 16 [130/295]	Loss:  0.249692
# Train Epoch : 16 [140/295]	Loss:  0.092147
# Train Epoch : 16 [150/295]	Loss:  0.094091
# Train Epoch : 16 [160/295]	Loss:  0.054031
# Train Epoch : 16 [170/295]	Loss:  0.390566
# Train Epoch : 16 [180/295]	Loss:  0.024641
# Train Epoch : 16 [190/295]	Loss:  0.061331
# Train Epoch : 16 [200/295]	Loss:  0.040648
# Train Epoch : 16 [210/295]	Loss:  0.083289
# Train Epoch : 16 [220/295]	Loss:  0.141659
# Train Epoch : 16 [230/295]	Loss:  0.088550
# Train Epoch : 16 [240/295]	Loss:  0.177385
# Train Epoch : 16 [250/295]	Loss:  0.064804
# Train Epoch : 16 [260/295]	Loss:  0.077268
# Train Epoch : 16 [270/295]	Loss:  0.302242
# Train Epoch : 16 [280/295]	Loss:  0.017524
# Train Epoch : 16 [290/295]	Loss:  0.017701
# Train Epoch : 17 [0/295]	Loss:  0.113273
# Train Epoch : 17 [10/295]	Loss:  0.035226
# Train Epoch : 17 [20/295]	Loss:  0.122445
# Train Epoch : 17 [30/295]	Loss:  0.116559
# Train Epoch : 17 [40/295]	Loss:  0.083140
# Train Epoch : 17 [50/295]	Loss:  0.246652
# Train Epoch : 17 [60/295]	Loss:  0.084181
# Train Epoch : 17 [70/295]	Loss:  0.079811
# Train Epoch : 17 [80/295]	Loss:  0.090736
# Train Epoch : 17 [90/295]	Loss:  0.056938
# Train Epoch : 17 [100/295]	Loss:  0.072837
# Train Epoch : 17 [110/295]	Loss:  0.119111
# Train Epoch : 17 [120/295]	Loss:  0.173379
# Train Epoch : 17 [130/295]	Loss:  0.256847
# Train Epoch : 17 [140/295]	Loss:  0.038500
# Train Epoch : 17 [150/295]	Loss:  0.218869
# Train Epoch : 17 [160/295]	Loss:  0.062168
# Train Epoch : 17 [170/295]	Loss:  0.141704
# Train Epoch : 17 [180/295]	Loss:  0.035327
# Train Epoch : 17 [190/295]	Loss:  0.138081
# Train Epoch : 17 [200/295]	Loss:  0.105020
# Train Epoch : 17 [210/295]	Loss:  0.075378
# Train Epoch : 17 [220/295]	Loss:  0.217178
# Train Epoch : 17 [230/295]	Loss:  0.067546
# Train Epoch : 17 [240/295]	Loss:  0.028565
# Train Epoch : 17 [250/295]	Loss:  0.134701
# Train Epoch : 17 [260/295]	Loss:  0.022566
# Train Epoch : 17 [270/295]	Loss:  0.053949
# Train Epoch : 17 [280/295]	Loss:  0.063975
# Train Epoch : 17 [290/295]	Loss:  0.033372
# Train Epoch : 18 [0/295]	Loss:  0.034592
# Train Epoch : 18 [10/295]	Loss:  0.148956
# Train Epoch : 18 [20/295]	Loss:  0.107533
# Train Epoch : 18 [30/295]	Loss:  0.042318
# Train Epoch : 18 [40/295]	Loss:  0.088471
# Train Epoch : 18 [50/295]	Loss:  0.246049
# Train Epoch : 18 [60/295]	Loss:  0.114823
# Train Epoch : 18 [70/295]	Loss:  0.200964
# Train Epoch : 18 [80/295]	Loss:  0.198109
# Train Epoch : 18 [90/295]	Loss:  0.042122
# Train Epoch : 18 [100/295]	Loss:  0.104103
# Train Epoch : 18 [110/295]	Loss:  0.114548
# Train Epoch : 18 [120/295]	Loss:  0.049055
# Train Epoch : 18 [130/295]	Loss:  0.037134
# Train Epoch : 18 [140/295]	Loss:  0.059423
# Train Epoch : 18 [150/295]	Loss:  0.144686
# Train Epoch : 18 [160/295]	Loss:  0.106160
# Train Epoch : 18 [170/295]	Loss:  0.070931
# Train Epoch : 18 [180/295]	Loss:  0.035951
# Train Epoch : 18 [190/295]	Loss:  0.039107
# Train Epoch : 18 [200/295]	Loss:  0.092386
# Train Epoch : 18 [210/295]	Loss:  0.068013
# Train Epoch : 18 [220/295]	Loss:  0.117362
# Train Epoch : 18 [230/295]	Loss:  0.013975
# Train Epoch : 18 [240/295]	Loss:  0.055490
# Train Epoch : 18 [250/295]	Loss:  0.149348
# Train Epoch : 18 [260/295]	Loss:  0.088129
# Train Epoch : 18 [270/295]	Loss:  0.065227
# Train Epoch : 18 [280/295]	Loss:  0.081007
# Train Epoch : 18 [290/295]	Loss:  0.069762
# Train Epoch : 19 [0/295]	Loss:  0.046640
# Train Epoch : 19 [10/295]	Loss:  0.075826
# Train Epoch : 19 [20/295]	Loss:  0.093747
# Train Epoch : 19 [30/295]	Loss:  0.209916
# Train Epoch : 19 [40/295]	Loss:  0.024431
# Train Epoch : 19 [50/295]	Loss:  0.030692
# Train Epoch : 19 [60/295]	Loss:  0.249114
# Train Epoch : 19 [70/295]	Loss:  0.030058
# Train Epoch : 19 [80/295]	Loss:  0.090596
# Train Epoch : 19 [90/295]	Loss:  0.094343
# Train Epoch : 19 [100/295]	Loss:  0.115979
# Train Epoch : 19 [110/295]	Loss:  0.079643
# Train Epoch : 19 [120/295]	Loss:  0.039783
# Train Epoch : 19 [130/295]	Loss:  0.216448
# Train Epoch : 19 [140/295]	Loss:  0.069219
# Train Epoch : 19 [150/295]	Loss:  0.227892
# Train Epoch : 19 [160/295]	Loss:  0.123254
# Train Epoch : 19 [170/295]	Loss:  0.104240
# Train Epoch : 19 [180/295]	Loss:  0.100892
# Train Epoch : 19 [190/295]	Loss:  0.135750
# Train Epoch : 19 [200/295]	Loss:  0.076733
# Train Epoch : 19 [210/295]	Loss:  0.102338
# Train Epoch : 19 [220/295]	Loss:  0.292635
# Train Epoch : 19 [230/295]	Loss:  0.081770
# Train Epoch : 19 [240/295]	Loss:  0.076315
# Train Epoch : 19 [250/295]	Loss:  0.139865
# Train Epoch : 19 [260/295]	Loss:  0.072370
# Train Epoch : 19 [270/295]	Loss:  0.100829
# Train Epoch : 19 [280/295]	Loss:  0.118264
# Train Epoch : 19 [290/295]	Loss:  0.061073
# Best model saved for EfficientNet_V2_M with accuracy: 96.9595
# Train Epoch : 20 [0/295]	Loss:  0.042765
# Train Epoch : 20 [10/295]	Loss:  0.072779
# Train Epoch : 20 [20/295]	Loss:  0.081618
# Train Epoch : 20 [30/295]	Loss:  0.042416
# Train Epoch : 20 [40/295]	Loss:  0.056837
# Train Epoch : 20 [50/295]	Loss:  0.077682
# Train Epoch : 20 [60/295]	Loss:  0.041804
# Train Epoch : 20 [70/295]	Loss:  0.141603
# Train Epoch : 20 [80/295]	Loss:  0.194313
# Train Epoch : 20 [90/295]	Loss:  0.053314
# Train Epoch : 20 [100/295]	Loss:  0.073825
# Train Epoch : 20 [110/295]	Loss:  0.171646
# Train Epoch : 20 [120/295]	Loss:  0.271181
# Train Epoch : 20 [130/295]	Loss:  0.038682
# Train Epoch : 20 [140/295]	Loss:  0.021273
# Train Epoch : 20 [150/295]	Loss:  0.061455
# Train Epoch : 20 [160/295]	Loss:  0.054000
# Train Epoch : 20 [170/295]	Loss:  0.147010
# Train Epoch : 20 [180/295]	Loss:  0.047533
# Train Epoch : 20 [190/295]	Loss:  0.019514
# Train Epoch : 20 [200/295]	Loss:  0.126793
# Train Epoch : 20 [210/295]	Loss:  0.147110
# Train Epoch : 20 [220/295]	Loss:  0.049880
# Train Epoch : 20 [230/295]	Loss:  0.170796
# Train Epoch : 20 [240/295]	Loss:  0.056948
# Train Epoch : 20 [250/295]	Loss:  0.080824
# Train Epoch : 20 [260/295]	Loss:  0.045958
# Train Epoch : 20 [270/295]	Loss:  0.123686
# Train Epoch : 20 [280/295]	Loss:  0.103354
# Train Epoch : 20 [290/295]	Loss:  0.220007
# Train Epoch : 21 [0/295]	Loss:  0.103488
# Train Epoch : 21 [10/295]	Loss:  0.445192
# Train Epoch : 21 [20/295]	Loss:  0.313768
# Train Epoch : 21 [30/295]	Loss:  0.043085
# Train Epoch : 21 [40/295]	Loss:  0.038851
# Train Epoch : 21 [50/295]	Loss:  0.090837
# Train Epoch : 21 [60/295]	Loss:  0.423863
# Train Epoch : 21 [70/295]	Loss:  0.029317
# Train Epoch : 21 [80/295]	Loss:  0.034144
# Train Epoch : 21 [90/295]	Loss:  0.127728
# Train Epoch : 21 [100/295]	Loss:  0.114407
# Train Epoch : 21 [110/295]	Loss:  0.019465
# Train Epoch : 21 [120/295]	Loss:  0.079950
# Train Epoch : 21 [130/295]	Loss:  0.055051
# Train Epoch : 21 [140/295]	Loss:  0.100197
# Train Epoch : 21 [150/295]	Loss:  0.029800
# Train Epoch : 21 [160/295]	Loss:  0.211408
# Train Epoch : 21 [220/295]	Loss:  0.131115
# Train Epoch : 21 [230/295]	Loss:  0.054926
# Train Epoch : 22 [70/295]	Loss:  0.034975
# Train Epoch : 22 [80/295]	Loss:  0.214574
# Train Epoch : 22 [90/295]	Loss:  0.266066
# Train Epoch : 22 [100/295]	Loss:  0.051592
# Train Epoch : 22 [110/295]	Loss:  0.092409
# Train Epoch : 22 [120/295]	Loss:  0.055770
# Train Epoch : 22 [130/295]	Loss:  0.079341
# Train Epoch : 22 [140/295]	Loss:  0.077628
# Train Epoch : 22 [150/295]	Loss:  0.114152
# Train Epoch : 22 [160/295]	Loss:  0.433513
# Train Epoch : 22 [170/295]	Loss:  0.047303
# Train Epoch : 22 [180/295]	Loss:  0.185360
# Train Epoch : 22 [190/295]	Loss:  0.048098
# Train Epoch : 22 [200/295]	Loss:  0.021113
# Train Epoch : 22 [210/295]	Loss:  0.158357
# Train Epoch : 22 [220/295]	Loss:  0.068501
# Train Epoch : 22 [230/295]	Loss:  0.116272
# Train Epoch : 22 [240/295]	Loss:  0.041720
# Train Epoch : 22 [250/295]	Loss:  0.092720
# Train Epoch : 22 [260/295]	Loss:  0.167619
# Train Epoch : 22 [270/295]	Loss:  0.153918
# Train Epoch : 22 [280/295]	Loss:  0.029842
# Train Epoch : 22 [290/295]	Loss:  0.075263
# Train Epoch : 23 [0/295]	Loss:  0.208054
# Train Epoch : 23 [10/295]	Loss:  0.215490
# Train Epoch : 23 [20/295]	Loss:  0.220522
# Train Epoch : 23 [30/295]	Loss:  0.071831
# Train Epoch : 23 [40/295]	Loss:  0.055988
# Train Epoch : 23 [50/295]	Loss:  0.066775
# Train Epoch : 23 [60/295]	Loss:  0.073757
# Train Epoch : 23 [70/295]	Loss:  0.072343
# Train Epoch : 23 [80/295]	Loss:  0.039812
# Train Epoch : 23 [90/295]	Loss:  0.035304
# Train Epoch : 23 [100/295]	Loss:  0.102220
# Train Epoch : 23 [110/295]	Loss:  0.063634
# Train Epoch : 23 [120/295]	Loss:  0.059986
# Train Epoch : 23 [130/295]	Loss:  0.048546
# Train Epoch : 23 [140/295]	Loss:  0.030301
# Train Epoch : 23 [150/295]	Loss:  0.039495
# Train Epoch : 23 [160/295]	Loss:  0.046609
# Train Epoch : 23 [170/295]	Loss:  0.118537
# Train Epoch : 23 [180/295]	Loss:  0.094575
# Train Epoch : 23 [190/295]	Loss:  0.078204
# Train Epoch : 23 [200/295]	Loss:  0.154414
# Train Epoch : 23 [210/295]	Loss:  0.034962
# Train Epoch : 23 [220/295]	Loss:  0.074870
# Train Epoch : 23 [230/295]	Loss:  0.094482
# Train Epoch : 23 [240/295]	Loss:  0.102943
# Train Epoch : 23 [250/295]	Loss:  0.272509
# Train Epoch : 23 [260/295]	Loss:  0.044600
# Train Epoch : 23 [270/295]	Loss:  0.060360
# Train Epoch : 23 [280/295]	Loss:  0.115415
# Train Epoch : 23 [290/295]	Loss:  0.023536
# Train Epoch : 24 [0/295]	Loss:  0.152186
# Train Epoch : 24 [10/295]	Loss:  0.138282
# Train Epoch : 24 [20/295]	Loss:  0.015629
# Train Epoch : 24 [30/295]	Loss:  0.458009
# Train Epoch : 24 [40/295]	Loss:  0.124242
# Train Epoch : 24 [50/295]	Loss:  0.035562
# Train Epoch : 24 [60/295]	Loss:  0.045078
# Train Epoch : 24 [70/295]	Loss:  0.017963
# Train Epoch : 24 [80/295]	Loss:  0.051583
# Train Epoch : 24 [90/295]	Loss:  0.018637
# Train Epoch : 24 [100/295]	Loss:  0.126470
# Train Epoch : 24 [110/295]	Loss:  0.069935
# Train Epoch : 24 [120/295]	Loss:  0.084097
# Train Epoch : 24 [130/295]	Loss:  0.024511
# Train Epoch : 24 [140/295]	Loss:  0.090770
# Train Epoch : 24 [150/295]	Loss:  0.044156
# Train Epoch : 24 [160/295]	Loss:  0.050150
# Train Epoch : 24 [170/295]	Loss:  0.026501
# Train Epoch : 24 [180/295]	Loss:  0.021096
# Train Epoch : 24 [190/295]	Loss:  0.030463
# Train Epoch : 24 [200/295]	Loss:  0.045668
# Train Epoch : 24 [210/295]	Loss:  0.051249
# Train Epoch : 24 [220/295]	Loss:  0.045379
# Train Epoch : 24 [230/295]	Loss:  0.091384
# Train Epoch : 24 [240/295]	Loss:  0.030363
# Train Epoch : 24 [250/295]	Loss:  0.022373
# Train Epoch : 24 [260/295]	Loss:  0.031411
# Train Epoch : 24 [270/295]	Loss:  0.251410
# Train Epoch : 24 [280/295]	Loss:  0.037277
# Train Epoch : 24 [290/295]	Loss:  0.042297
# Train Epoch : 25 [0/295]	Loss:  0.183956
# Train Epoch : 25 [10/295]	Loss:  0.023842
# Train Epoch : 25 [20/295]	Loss:  0.028491
# Train Epoch : 25 [30/295]	Loss:  0.049125
# Train Epoch : 25 [40/295]	Loss:  0.037666
# Train Epoch : 25 [50/295]	Loss:  0.018296
# Train Epoch : 25 [60/295]	Loss:  0.141896
# Train Epoch : 25 [70/295]	Loss:  0.134933
# Train Epoch : 25 [80/295]	Loss:  0.100650
# Train Epoch : 25 [90/295]	Loss:  0.169839
# Train Epoch : 25 [100/295]	Loss:  0.044768
# Train Epoch : 25 [110/295]	Loss:  0.023919
# Train Epoch : 25 [120/295]	Loss:  0.025364
# Train Epoch : 25 [130/295]	Loss:  0.074364
# Train Epoch : 25 [140/295]	Loss:  0.245143
# Train Epoch : 25 [150/295]	Loss:  0.106224
# Train Epoch : 25 [160/295]	Loss:  0.077410
# Train Epoch : 25 [170/295]	Loss:  0.139986
# Train Epoch : 25 [180/295]	Loss:  0.120051
# Train Epoch : 25 [190/295]	Loss:  0.142602
# Train Epoch : 25 [200/295]	Loss:  0.074531
# Train Epoch : 25 [210/295]	Loss:  0.108032
# Train Epoch : 25 [220/295]	Loss:  0.061040
# Train Epoch : 25 [230/295]	Loss:  0.073237
# Train Epoch : 25 [240/295]	Loss:  0.180558
# Train Epoch : 25 [250/295]	Loss:  0.120849
# Train Epoch : 25 [260/295]	Loss:  0.018811
# Train Epoch : 25 [270/295]	Loss:  0.185539
# Train Epoch : 25 [280/295]	Loss:  0.016876
# Train Epoch : 25 [290/295]	Loss:  0.102260
# Train Epoch : 26 [0/295]	Loss:  0.091515
# Train Epoch : 26 [10/295]	Loss:  0.037949
# Train Epoch : 26 [20/295]	Loss:  0.040402
# Train Epoch : 26 [30/295]	Loss:  0.268514
# Train Epoch : 26 [40/295]	Loss:  0.100185
# Train Epoch : 26 [50/295]	Loss:  0.071854
# Train Epoch : 26 [60/295]	Loss:  0.079092
# Train Epoch : 26 [70/295]	Loss:  0.190657
# Train Epoch : 26 [80/295]	Loss:  0.076409
# Train Epoch : 26 [90/295]	Loss:  0.294783
# Train Epoch : 26 [100/295]	Loss:  0.070592
# Train Epoch : 26 [110/295]	Loss:  0.063016
# Train Epoch : 26 [120/295]	Loss:  0.044485
# Train Epoch : 26 [130/295]	Loss:  0.046674
# Train Epoch : 26 [140/295]	Loss:  0.022695
# Train Epoch : 26 [150/295]	Loss:  0.014989
# Train Epoch : 26 [160/295]	Loss:  0.024132
# Train Epoch : 26 [170/295]	Loss:  0.014110
# Train Epoch : 26 [180/295]	Loss:  0.029179
# Train Epoch : 26 [190/295]	Loss:  0.063725
# Train Epoch : 26 [200/295]	Loss:  0.027152
# Train Epoch : 26 [210/295]	Loss:  0.016178
# Train Epoch : 26 [220/295]	Loss:  0.053925
# Train Epoch : 26 [230/295]	Loss:  0.108982
# Train Epoch : 26 [240/295]	Loss:  0.058472
# Train Epoch : 26 [250/295]	Loss:  0.012900
# Train Epoch : 26 [260/295]	Loss:  0.039544
# Train Epoch : 26 [270/295]	Loss:  0.146848
# Train Epoch : 26 [280/295]	Loss:  0.100175
# Train Epoch : 26 [290/295]	Loss:  0.064361
# Train Epoch : 27 [0/295]	Loss:  0.147929
# Train Epoch : 27 [10/295]	Loss:  0.068768
# Train Epoch : 27 [20/295]	Loss:  0.034657
# Train Epoch : 27 [30/295]	Loss:  0.174346
# Train Epoch : 27 [40/295]	Loss:  0.064574
# Train Epoch : 27 [50/295]	Loss:  0.123022
# Train Epoch : 27 [60/295]	Loss:  0.035626
# Train Epoch : 27 [70/295]	Loss:  0.049127
# Train Epoch : 27 [80/295]	Loss:  0.069375
# Train Epoch : 27 [90/295]	Loss:  0.168475
# Train Epoch : 27 [100/295]	Loss:  0.115203
# Train Epoch : 27 [110/295]	Loss:  0.501739
# Train Epoch : 27 [120/295]	Loss:  0.051171
# Train Epoch : 27 [130/295]	Loss:  0.036338
# Train Epoch : 27 [140/295]	Loss:  0.018285
# Train Epoch : 27 [150/295]	Loss:  0.030984
# Train Epoch : 27 [160/295]	Loss:  0.046527
# Train Epoch : 27 [170/295]	Loss:  0.204821
# Train Epoch : 27 [180/295]	Loss:  0.029790
# Train Epoch : 27 [190/295]	Loss:  0.118376
# Train Epoch : 27 [200/295]	Loss:  0.113193
# Train Epoch : 27 [210/295]	Loss:  0.026410
# Train Epoch : 27 [220/295]	Loss:  0.072413
# Train Epoch : 27 [230/295]	Loss:  0.020039
# Train Epoch : 27 [240/295]	Loss:  0.050186
# Train Epoch : 27 [250/295]	Loss:  0.006135
# Train Epoch : 27 [260/295]	Loss:  0.057268
# Train Epoch : 27 [270/295]	Loss:  0.102599
# Train Epoch : 27 [280/295]	Loss:  0.130695
# Train Epoch : 27 [290/295]	Loss:  0.050588
# Train Epoch : 28 [0/295]	Loss:  0.043704
# Train Epoch : 28 [10/295]	Loss:  0.066630
# Train Epoch : 28 [20/295]	Loss:  0.056744
# Train Epoch : 28 [30/295]	Loss:  0.055382
# Train Epoch : 28 [40/295]	Loss:  0.019030
# Train Epoch : 28 [50/295]	Loss:  0.059585
# Train Epoch : 28 [60/295]	Loss:  0.034315
# Train Epoch : 28 [70/295]	Loss:  0.035801
# Train Epoch : 28 [80/295]	Loss:  0.114219
# Train Epoch : 28 [90/295]	Loss:  0.071319
# Train Epoch : 28 [100/295]	Loss:  0.045139
# Train Epoch : 28 [110/295]	Loss:  0.032866
# Train Epoch : 28 [120/295]	Loss:  0.029139
# Train Epoch : 28 [130/295]	Loss:  0.014991
# Train Epoch : 28 [140/295]	Loss:  0.050535
# Train Epoch : 28 [150/295]	Loss:  0.273636
# Train Epoch : 28 [160/295]	Loss:  0.014758
# Train Epoch : 28 [170/295]	Loss:  0.044412
# Train Epoch : 28 [180/295]	Loss:  0.033983
# Train Epoch : 28 [190/295]	Loss:  0.021724
# Train Epoch : 28 [200/295]	Loss:  0.013742
# Train Epoch : 28 [210/295]	Loss:  0.052878
# Train Epoch : 28 [220/295]	Loss:  0.096575
# Train Epoch : 28 [230/295]	Loss:  0.033091
# Train Epoch : 28 [240/295]	Loss:  0.055409
# Train Epoch : 28 [250/295]	Loss:  0.020758
# Train Epoch : 28 [260/295]	Loss:  0.057832
# Train Epoch : 28 [270/295]	Loss:  0.022417
# Train Epoch : 28 [280/295]	Loss:  0.401931
# Train Epoch : 28 [290/295]	Loss:  0.081287
# Train Epoch : 29 [0/295]	Loss:  0.112410
# Train Epoch : 29 [10/295]	Loss:  0.037281
# Train Epoch : 29 [20/295]	Loss:  0.129094
# Train Epoch : 29 [30/295]	Loss:  0.122432
# Train Epoch : 29 [40/295]	Loss:  0.048074
# Train Epoch : 29 [50/295]	Loss:  0.007214
# Train Epoch : 29 [60/295]	Loss:  0.063370
# Train Epoch : 29 [70/295]	Loss:  0.050678
# Train Epoch : 29 [80/295]	Loss:  0.064849
# Train Epoch : 29 [90/295]	Loss:  0.089673
# Train Epoch : 29 [100/295]	Loss:  0.104202
# Train Epoch : 29 [110/295]	Loss:  0.028696
# Train Epoch : 29 [120/295]	Loss:  0.039243
# Train Epoch : 29 [130/295]	Loss:  0.029324
# Train Epoch : 29 [140/295]	Loss:  0.053048
# Train Epoch : 29 [150/295]	Loss:  0.039702
# Train Epoch : 29 [160/295]	Loss:  0.083774
# Train Epoch : 29 [170/295]	Loss:  0.013147
# Train Epoch : 29 [180/295]	Loss:  0.034866
# Train Epoch : 29 [190/295]	Loss:  0.083456
# Train Epoch : 29 [200/295]	Loss:  0.026678
# Train Epoch : 29 [210/295]	Loss:  0.012245
# Train Epoch : 29 [220/295]	Loss:  0.060953
# Train Epoch : 29 [230/295]	Loss:  0.061163
# Train Epoch : 29 [240/295]	Loss:  0.057266
# Train Epoch : 29 [250/295]	Loss:  0.063483
# Train Epoch : 29 [260/295]	Loss:  0.023555
# Train Epoch : 29 [270/295]	Loss:  0.016362
# Train Epoch : 29 [280/295]	Loss:  0.146293
# Train Epoch : 29 [290/295]	Loss:  0.014693
# Train Epoch : 30 [0/295]	Loss:  0.049956
# Train Epoch : 30 [10/295]	Loss:  0.069089
# Train Epoch : 30 [20/295]	Loss:  0.028466
# Train Epoch : 30 [30/295]	Loss:  0.130975
# Train Epoch : 30 [40/295]	Loss:  0.040475
# Train Epoch : 30 [50/295]	Loss:  0.113219
# Train Epoch : 30 [60/295]	Loss:  0.054030
# Train Epoch : 30 [70/295]	Loss:  0.041855
# Train Epoch : 30 [80/295]	Loss:  0.030612
# Train Epoch : 30 [90/295]	Loss:  0.050783
# Train Epoch : 30 [100/295]	Loss:  0.031917
# Train Epoch : 30 [110/295]	Loss:  0.072105
# Train Epoch : 30 [120/295]	Loss:  0.033157
# Train Epoch : 30 [130/295]	Loss:  0.026609
# Train Epoch : 30 [140/295]	Loss:  0.035810
# Train Epoch : 30 [150/295]	Loss:  0.059960
# Train Epoch : 30 [160/295]	Loss:  0.028616
# Train Epoch : 30 [170/295]	Loss:  0.052104
# Train Epoch : 30 [180/295]	Loss:  0.006573
# Train Epoch : 30 [190/295]	Loss:  0.153079
# Train Epoch : 30 [200/295]	Loss:  0.046338
# Train Epoch : 30 [210/295]	Loss:  0.061412
# Train Epoch : 30 [220/295]	Loss:  0.054222
# Train Epoch : 30 [230/295]	Loss:  0.086458
# Train Epoch : 30 [240/295]	Loss:  0.053516
# Train Epoch : 30 [250/295]	Loss:  0.037671
# Train Epoch : 30 [260/295]	Loss:  0.035036
# Train Epoch : 30 [270/295]	Loss:  0.011063
# Train Epoch : 30 [280/295]	Loss:  0.060274
# Train Epoch : 30 [290/295]	Loss:  0.049040
# Train Epoch : 31 [0/295]	Loss:  0.049118
# Train Epoch : 31 [10/295]	Loss:  0.186942
# Train Epoch : 31 [20/295]	Loss:  0.004614
# Train Epoch : 31 [30/295]	Loss:  0.107700
# Train Epoch : 31 [40/295]	Loss:  0.049864
# Train Epoch : 31 [50/295]	Loss:  0.087392
# Train Epoch : 31 [60/295]	Loss:  0.015077
# Train Epoch : 31 [70/295]	Loss:  0.058755
# Train Epoch : 31 [80/295]	Loss:  0.068821
# Train Epoch : 31 [90/295]	Loss:  0.018288
# Train Epoch : 31 [100/295]	Loss:  0.104414
# Train Epoch : 31 [110/295]	Loss:  0.048063
# Train Epoch : 31 [120/295]	Loss:  0.009771
# Train Epoch : 31 [130/295]	Loss:  0.039534
# Train Epoch : 31 [140/295]	Loss:  0.046485
# Train Epoch : 31 [150/295]	Loss:  0.021479
# Train Epoch : 31 [160/295]	Loss:  0.012989
# Train Epoch : 31 [170/295]	Loss:  0.043619
# Train Epoch : 31 [180/295]	Loss:  0.138140
# Train Epoch : 31 [190/295]	Loss:  0.034596
# Train Epoch : 31 [200/295]	Loss:  0.041431
# Train Epoch : 31 [210/295]	Loss:  0.029527
# Train Epoch : 31 [220/295]	Loss:  0.044155
# Train Epoch : 31 [230/295]	Loss:  0.013353
# Train Epoch : 31 [240/295]	Loss:  0.021883
# Train Epoch : 31 [250/295]	Loss:  0.119541
# Train Epoch : 31 [260/295]	Loss:  0.078555
# Train Epoch : 31 [270/295]	Loss:  0.014570
# Train Epoch : 31 [280/295]	Loss:  0.029367
# Train Epoch : 31 [290/295]	Loss:  0.176068
# Train Epoch : 32 [0/295]	Loss:  0.043520
# Train Epoch : 32 [10/295]	Loss:  0.037776
# Train Epoch : 32 [20/295]	Loss:  0.011278
# Train Epoch : 32 [30/295]	Loss:  0.109082
# Train Epoch : 32 [40/295]	Loss:  0.083478
# Train Epoch : 32 [50/295]	Loss:  0.061559
# Train Epoch : 32 [60/295]	Loss:  0.222080
# Train Epoch : 32 [70/295]	Loss:  0.036760
# Train Epoch : 32 [80/295]	Loss:  0.065804
# Train Epoch : 32 [90/295]	Loss:  0.038110
# Train Epoch : 32 [100/295]	Loss:  0.019022
# Train Epoch : 32 [110/295]	Loss:  0.174445
# Train Epoch : 32 [120/295]	Loss:  0.066489
# Train Epoch : 32 [130/295]	Loss:  0.006231
# Train Epoch : 32 [140/295]	Loss:  0.072516
# Train Epoch : 32 [150/295]	Loss:  0.121473
# Train Epoch : 32 [160/295]	Loss:  0.020491
# Train Epoch : 32 [170/295]	Loss:  0.042752
# Train Epoch : 32 [180/295]	Loss:  0.018473
# Train Epoch : 32 [190/295]	Loss:  0.153239
# Train Epoch : 32 [200/295]	Loss:  0.034965
# Train Epoch : 32 [210/295]	Loss:  0.019773
# Train Epoch : 32 [220/295]	Loss:  0.068051
# Train Epoch : 32 [230/295]	Loss:  0.173154
# Train Epoch : 32 [240/295]	Loss:  0.125317
# Train Epoch : 32 [250/295]	Loss:  0.054851
# Train Epoch : 32 [260/295]	Loss:  0.032969
# Train Epoch : 32 [270/295]	Loss:  0.045064
# Train Epoch : 32 [280/295]	Loss:  0.046333
# Train Epoch : 32 [290/295]	Loss:  0.017820
# Train Epoch : 33 [0/295]	Loss:  0.158388
# Train Epoch : 33 [10/295]	Loss:  0.008857
# Train Epoch : 33 [20/295]	Loss:  0.210218
# Train Epoch : 33 [30/295]	Loss:  0.011611
# Train Epoch : 33 [40/295]	Loss:  0.321851
# Train Epoch : 33 [50/295]	Loss:  0.027994
# Train Epoch : 33 [60/295]	Loss:  0.080636
# Train Epoch : 33 [70/295]	Loss:  0.038759
# Train Epoch : 33 [80/295]	Loss:  0.083024
# Train Epoch : 33 [90/295]	Loss:  0.028192
# Train Epoch : 33 [100/295]	Loss:  0.043816
# Train Epoch : 33 [110/295]	Loss:  0.048595
# Train Epoch : 33 [120/295]	Loss:  0.043650
# Train Epoch : 33 [130/295]	Loss:  0.053845
# Train Epoch : 33 [140/295]	Loss:  0.032266
# Train Epoch : 33 [150/295]	Loss:  0.022419
# Train Epoch : 33 [160/295]	Loss:  0.020844
# Train Epoch : 33 [170/295]	Loss:  0.013059
# Train Epoch : 33 [180/295]	Loss:  0.018119
# Train Epoch : 33 [190/295]	Loss:  0.091220
# Train Epoch : 33 [200/295]	Loss:  0.018985
# Train Epoch : 33 [210/295]	Loss:  0.019874
# Train Epoch : 33 [220/295]	Loss:  0.074118
# Train Epoch : 33 [230/295]	Loss:  0.051282
# Train Epoch : 33 [240/295]	Loss:  0.038500
# Train Epoch : 33 [250/295]	Loss:  0.034731
# Train Epoch : 33 [260/295]	Loss:  0.018252
# Train Epoch : 33 [270/295]	Loss:  0.045984
# Train Epoch : 33 [280/295]	Loss:  0.009003
# Train Epoch : 33 [290/295]	Loss:  0.039949
# Train Epoch : 34 [0/295]	Loss:  0.014037
# Train Epoch : 34 [10/295]	Loss:  0.170695
# Train Epoch : 34 [20/295]	Loss:  0.096776
# Train Epoch : 34 [30/295]	Loss:  0.040217
# Train Epoch : 34 [40/295]	Loss:  0.018372
# Train Epoch : 34 [50/295]	Loss:  0.056180
# Train Epoch : 34 [60/295]	Loss:  0.013555
# Train Epoch : 34 [70/295]	Loss:  0.166215
# Train Epoch : 34 [80/295]	Loss:  0.019241
# Train Epoch : 34 [90/295]	Loss:  0.090104
# Train Epoch : 34 [100/295]	Loss:  0.018740
# Train Epoch : 34 [110/295]	Loss:  0.132669
# Train Epoch : 34 [120/295]	Loss:  0.039151
# Train Epoch : 34 [130/295]	Loss:  0.255219
# Train Epoch : 34 [140/295]	Loss:  0.036080
# Train Epoch : 34 [150/295]	Loss:  0.030346
# Train Epoch : 34 [160/295]	Loss:  0.034985
# Train Epoch : 34 [170/295]	Loss:  0.069043
# Train Epoch : 34 [180/295]	Loss:  0.030996
# Train Epoch : 34 [190/295]	Loss:  0.058751
# Train Epoch : 34 [200/295]	Loss:  0.026842
# Train Epoch : 34 [210/295]	Loss:  0.010254
# Train Epoch : 34 [220/295]	Loss:  0.011940
# Train Epoch : 34 [230/295]	Loss:  0.014457
# Train Epoch : 34 [240/295]	Loss:  0.024855
# Train Epoch : 34 [250/295]	Loss:  0.194183
# Train Epoch : 34 [260/295]	Loss:  0.063968
# Train Epoch : 34 [270/295]	Loss:  0.062740
# Train Epoch : 34 [280/295]	Loss:  0.047509
# Train Epoch : 34 [290/295]	Loss:  0.050833
# Train Epoch : 35 [0/295]	Loss:  0.182455
# Train Epoch : 35 [10/295]	Loss:  0.022500
# Train Epoch : 35 [20/295]	Loss:  0.048731
# Train Epoch : 35 [30/295]	Loss:  0.033163
# Train Epoch : 35 [40/295]	Loss:  0.069931
# Train Epoch : 35 [50/295]	Loss:  0.043309
# Train Epoch : 35 [60/295]	Loss:  0.067045
# Train Epoch : 35 [70/295]	Loss:  0.132840
# Train Epoch : 35 [80/295]	Loss:  0.068478
# Train Epoch : 35 [90/295]	Loss:  0.024369
# Train Epoch : 35 [100/295]	Loss:  0.031088
# Train Epoch : 35 [110/295]	Loss:  0.046890
# Train Epoch : 35 [120/295]	Loss:  0.012976
# Train Epoch : 35 [130/295]	Loss:  0.055367
# Train Epoch : 35 [140/295]	Loss:  0.171166
# Train Epoch : 35 [150/295]	Loss:  0.011364
# Train Epoch : 35 [160/295]	Loss:  0.011539
# Train Epoch : 35 [170/295]	Loss:  0.013225
# Train Epoch : 35 [180/295]	Loss:  0.026273
# Train Epoch : 35 [190/295]	Loss:  0.048907
# Train Epoch : 35 [200/295]	Loss:  0.040571
# Train Epoch : 35 [210/295]	Loss:  0.049417
# Train Epoch : 35 [220/295]	Loss:  0.018542
# Train Epoch : 35 [230/295]	Loss:  0.049426
# Train Epoch : 35 [240/295]	Loss:  0.018532
# Train Epoch : 35 [250/295]	Loss:  0.031253
# Train Epoch : 35 [260/295]	Loss:  0.011601
# Train Epoch : 35 [270/295]	Loss:  0.023757
# Train Epoch : 35 [280/295]	Loss:  0.027266
# Train Epoch : 35 [290/295]	Loss:  0.039872
# Train Epoch : 36 [0/295]	Loss:  0.075075
# Train Epoch : 36 [10/295]	Loss:  0.019507
# Train Epoch : 36 [20/295]	Loss:  0.053612
# Train Epoch : 36 [30/295]	Loss:  0.055652
# Train Epoch : 36 [40/295]	Loss:  0.172658
# Train Epoch : 36 [50/295]	Loss:  0.069578
# Train Epoch : 36 [60/295]	Loss:  0.047647
# ...
# Train Epoch : 42 [10/295]	Loss:  1.493722
# Train Epoch : 42 [20/295]	Loss:  0.099587
# Train Epoch : 42 [30/295]	Loss:  0.898664
# Train Epoch : 42 [40/295]	Loss:  0.364454
# Train Epoch : 42 [50/295]	Loss:  0.705601
# Train Epoch : 42 [60/295]	Loss:  0.713483
# Train Epoch : 42 [70/295]	Loss:  0.214888
# Train Epoch : 42 [80/295]	Loss:  1.596753
# Train Epoch : 42 [90/295]	Loss:  0.675115
# Train Epoch : 42 [100/295]	Loss:  0.147506
# Train Epoch : 42 [110/295]	Loss:  0.922931
# Train Epoch : 42 [120/295]	Loss:  0.333634
# Train Epoch : 42 [130/295]	Loss:  0.031188
# Train Epoch : 42 [140/295]	Loss:  0.513488
# Train Epoch : 42 [150/295]	Loss:  0.684666
# Train Epoch : 42 [160/295]	Loss:  0.989120
# Train Epoch : 42 [170/295]	Loss:  1.768208
# Train Epoch : 42 [180/295]	Loss:  0.656137
# Train Epoch : 42 [190/295]	Loss:  0.686141
# Train Epoch : 42 [200/295]	Loss:  0.085586
# Train Epoch : 42 [210/295]	Loss:  0.532440
# Train Epoch : 42 [220/295]	Loss:  0.160997
# Train Epoch : 42 [230/295]	Loss:  0.640239
# Train Epoch : 42 [240/295]	Loss:  0.687601
# Train Epoch : 42 [250/295]	Loss:  0.551227
# Train Epoch : 42 [260/295]	Loss:  1.655746
# Train Epoch : 42 [270/295]	Loss:  1.045085
# Train Epoch : 42 [280/295]	Loss:  0.086474
# Train Epoch : 42 [290/295]	Loss:  0.267118
# Train Epoch : 43 [0/295]	Loss:  0.266002
# Train Epoch : 43 [10/295]	Loss:  0.055729
# Train Epoch : 43 [20/295]	Loss:  0.109332
# Train Epoch : 43 [30/295]	Loss:  0.000518
# Train Epoch : 43 [40/295]	Loss:  0.009813
# Train Epoch : 43 [50/295]	Loss:  1.101026
# Train Epoch : 43 [60/295]	Loss:  0.080345
# Train Epoch : 43 [70/295]	Loss:  0.025945
# Train Epoch : 43 [80/295]	Loss:  1.024262
# Train Epoch : 43 [90/295]	Loss:  0.477034
# Train Epoch : 43 [100/295]	Loss:  0.200060
# Train Epoch : 43 [110/295]	Loss:  0.574157
# Train Epoch : 43 [120/295]	Loss:  0.380095
# Train Epoch : 43 [130/295]	Loss:  0.047215
# Train Epoch : 43 [140/295]	Loss:  0.650672
# Train Epoch : 43 [150/295]	Loss:  0.165463
# Train Epoch : 43 [160/295]	Loss:  0.656274
# Train Epoch : 43 [170/295]	Loss:  0.786350
# Train Epoch : 43 [180/295]	Loss:  1.519035
# Train Epoch : 43 [190/295]	Loss:  0.340023
# Train Epoch : 43 [200/295]	Loss:  0.036163
# Train Epoch : 43 [210/295]	Loss:  0.474312
# Train Epoch : 43 [220/295]	Loss:  1.786603
# Train Epoch : 43 [230/295]	Loss:  1.755090
# Train Epoch : 43 [240/295]	Loss:  0.156638
# Train Epoch : 43 [250/295]	Loss:  0.119402
# Train Epoch : 43 [260/295]	Loss:  0.651329
# Train Epoch : 43 [270/295]	Loss:  0.818680
# Train Epoch : 43 [280/295]	Loss:  0.574200
# Train Epoch : 43 [290/295]	Loss:  0.276101
# Train Epoch : 44 [0/295]	Loss:  1.524092
# Train Epoch : 44 [10/295]	Loss:  0.206378
# Train Epoch : 44 [20/295]	Loss:  0.292778
# Train Epoch : 44 [30/295]	Loss:  0.002049
# Train Epoch : 44 [40/295]	Loss:  0.074381
# Train Epoch : 44 [50/295]	Loss:  1.898007
# Train Epoch : 44 [60/295]	Loss:  0.905013
# Train Epoch : 44 [70/295]	Loss:  0.070431
# Train Epoch : 44 [80/295]	Loss:  0.379357
# Train Epoch : 44 [90/295]	Loss:  0.238473
# Train Epoch : 44 [100/295]	Loss:  0.576371
# Train Epoch : 44 [110/295]	Loss:  0.256607
# Train Epoch : 44 [120/295]	Loss:  0.613470
# Train Epoch : 44 [130/295]	Loss:  0.203380
# Train Epoch : 44 [140/295]	Loss:  0.341782
# Train Epoch : 44 [150/295]	Loss:  0.744396
# Train Epoch : 44 [160/295]	Loss:  0.767884
# Train Epoch : 44 [170/295]	Loss:  0.354905
# Train Epoch : 44 [180/295]	Loss:  0.753677
# Train Epoch : 44 [190/295]	Loss:  0.415196
# Train Epoch : 44 [200/295]	Loss:  0.671934
# Train Epoch : 44 [210/295]	Loss:  0.140016
# Train Epoch : 44 [220/295]	Loss:  0.099878
# Train Epoch : 44 [230/295]	Loss:  2.160063
# Train Epoch : 44 [240/295]	Loss:  0.540452
# Train Epoch : 44 [250/295]	Loss:  0.719281
# Train Epoch : 44 [260/295]	Loss:  0.233973
# Train Epoch : 44 [270/295]	Loss:  0.301722
# Train Epoch : 44 [280/295]	Loss:  0.215626
# Train Epoch : 44 [290/295]	Loss:  0.409787
# Train Epoch : 45 [0/295]	Loss:  2.698552
# Train Epoch : 45 [10/295]	Loss:  1.453402
# Train Epoch : 45 [20/295]	Loss:  0.734818
# Train Epoch : 45 [30/295]	Loss:  0.282962
# Train Epoch : 45 [40/295]	Loss:  0.743779
# Train Epoch : 45 [50/295]	Loss:  0.616032
# Train Epoch : 45 [60/295]	Loss:  0.584242
# Train Epoch : 45 [70/295]	Loss:  0.865325
# Train Epoch : 45 [80/295]	Loss:  1.832085
# Train Epoch : 45 [90/295]	Loss:  0.032528
# Train Epoch : 45 [100/295]	Loss:  0.023048
# Train Epoch : 45 [110/295]	Loss:  0.799667
# Train Epoch : 45 [120/295]	Loss:  0.005369
# Train Epoch : 45 [130/295]	Loss:  1.100795
# Train Epoch : 45 [140/295]	Loss:  1.716555
# Train Epoch : 45 [150/295]	Loss:  1.225197
# Train Epoch : 45 [160/295]	Loss:  0.128081
# Train Epoch : 45 [170/295]	Loss:  0.204143
# Train Epoch : 45 [180/295]	Loss:  0.119371
# Train Epoch : 45 [190/295]	Loss:  1.273888
# Train Epoch : 45 [200/295]	Loss:  0.451517
# Train Epoch : 45 [210/295]	Loss:  0.175515
# Train Epoch : 45 [220/295]	Loss:  0.429435
# Train Epoch : 45 [230/295]	Loss:  0.653824
# Train Epoch : 45 [240/295]	Loss:  0.175032
# Train Epoch : 45 [250/295]	Loss:  0.132375
# Train Epoch : 45 [260/295]	Loss:  0.682132
# Train Epoch : 45 [270/295]	Loss:  0.633669
# Train Epoch : 45 [280/295]	Loss:  1.084842
# Train Epoch : 45 [290/295]	Loss:  0.742717
# Train Epoch : 46 [0/295]	Loss:  0.814985
# Train Epoch : 46 [10/295]	Loss:  0.530195
# Train Epoch : 46 [20/295]	Loss:  0.601664
# Train Epoch : 46 [30/295]	Loss:  0.716426
# Train Epoch : 46 [40/295]	Loss:  0.021219
# Train Epoch : 46 [50/295]	Loss:  0.118880
# Train Epoch : 46 [60/295]	Loss:  0.164330
# Train Epoch : 46 [70/295]	Loss:  0.020373
# Train Epoch : 46 [80/295]	Loss:  0.380597
# Train Epoch : 46 [90/295]	Loss:  0.220729
# Train Epoch : 46 [100/295]	Loss:  0.521244
# Train Epoch : 46 [110/295]	Loss:  0.237163
# Train Epoch : 46 [120/295]	Loss:  0.527420
# Train Epoch : 46 [130/295]	Loss:  0.965953
# Train Epoch : 46 [140/295]	Loss:  0.316595
# Train Epoch : 46 [150/295]	Loss:  0.236541
# Train Epoch : 46 [160/295]	Loss:  0.384822
# Train Epoch : 46 [170/295]	Loss:  1.258577
# Train Epoch : 46 [180/295]	Loss:  0.849964
# Train Epoch : 46 [190/295]	Loss:  0.528929
# Train Epoch : 46 [200/295]	Loss:  0.256686
# Train Epoch : 46 [210/295]	Loss:  0.418350
# Train Epoch : 46 [220/295]	Loss:  1.386355
# Train Epoch : 46 [230/295]	Loss:  0.894162
# Train Epoch : 46 [240/295]	Loss:  0.086293
# Train Epoch : 46 [250/295]	Loss:  0.044618
# Train Epoch : 46 [260/295]	Loss:  0.372123
# Train Epoch : 46 [270/295]	Loss:  0.310964
# Train Epoch : 46 [280/295]	Loss:  0.303162
# Train Epoch : 46 [290/295]	Loss:  0.785835
# Train Epoch : 47 [0/295]	Loss:  0.116206
# Train Epoch : 47 [10/295]	Loss:  0.334397
# Train Epoch : 47 [20/295]	Loss:  0.326149
# Train Epoch : 47 [30/295]	Loss:  1.414002
# Train Epoch : 47 [40/295]	Loss:  0.446745
# Train Epoch : 47 [50/295]	Loss:  0.000317
# Train Epoch : 47 [60/295]	Loss:  0.191073
# Train Epoch : 47 [70/295]	Loss:  0.756024
# Train Epoch : 47 [80/295]	Loss:  0.000870
# Train Epoch : 47 [90/295]	Loss:  0.305817
# Train Epoch : 47 [100/295]	Loss:  0.050226
# Train Epoch : 47 [110/295]	Loss:  1.260458
# Train Epoch : 47 [120/295]	Loss:  0.259537
# Train Epoch : 47 [130/295]	Loss:  0.051450
# Train Epoch : 47 [140/295]	Loss:  0.657388
# Train Epoch : 47 [150/295]	Loss:  0.113587
# Train Epoch : 47 [160/295]	Loss:  0.306624
# Train Epoch : 47 [170/295]	Loss:  0.638138
# Train Epoch : 47 [180/295]	Loss:  1.006799
# Train Epoch : 47 [190/295]	Loss:  0.369489
# Train Epoch : 47 [200/295]	Loss:  0.071702
# Train Epoch : 47 [210/295]	Loss:  0.029021
# Train Epoch : 47 [220/295]	Loss:  0.309297
# Train Epoch : 47 [230/295]	Loss:  0.408696
# Train Epoch : 47 [240/295]	Loss:  0.346577
# Train Epoch : 47 [250/295]	Loss:  1.077283
# Train Epoch : 47 [260/295]	Loss:  0.601005
# Train Epoch : 47 [270/295]	Loss:  1.480752
# Train Epoch : 47 [280/295]	Loss:  0.729157
# Train Epoch : 47 [290/295]	Loss:  1.074280
# Train Epoch : 48 [0/295]	Loss:  0.868051
# Train Epoch : 48 [10/295]	Loss:  0.297375
# Train Epoch : 48 [20/295]	Loss:  1.313129
# Train Epoch : 48 [30/295]	Loss:  0.987468
# Train Epoch : 48 [40/295]	Loss:  0.010917
# Train Epoch : 48 [50/295]	Loss:  0.421664
# Train Epoch : 48 [60/295]	Loss:  0.297146
# Train Epoch : 48 [70/295]	Loss:  0.107222
# Train Epoch : 48 [80/295]	Loss:  0.800560
# Train Epoch : 48 [90/295]	Loss:  0.531163
# Train Epoch : 48 [100/295]	Loss:  0.182206
# Train Epoch : 48 [110/295]	Loss:  0.744833
# Train Epoch : 48 [120/295]	Loss:  0.192375
# Train Epoch : 48 [130/295]	Loss:  0.127865
# Train Epoch : 48 [140/295]	Loss:  0.559707
# Train Epoch : 48 [150/295]	Loss:  0.622730
# Train Epoch : 48 [160/295]	Loss:  0.906959
# Train Epoch : 48 [170/295]	Loss:  0.399135
# Train Epoch : 48 [180/295]	Loss:  0.860592
# Train Epoch : 48 [190/295]	Loss:  0.949713
# Train Epoch : 48 [200/295]	Loss:  0.543530
# Train Epoch : 48 [210/295]	Loss:  0.041060
# Train Epoch : 48 [220/295]	Loss:  0.125904
# Train Epoch : 48 [230/295]	Loss:  1.024268
# Train Epoch : 48 [240/295]	Loss:  0.034136
# Train Epoch : 48 [250/295]	Loss:  0.483759
# Train Epoch : 48 [260/295]	Loss:  0.214851
# Train Epoch : 48 [270/295]	Loss:  0.447573
# Train Epoch : 48 [280/295]	Loss:  0.113973
# Train Epoch : 48 [290/295]	Loss:  0.348137
# Train Epoch : 49 [0/295]	Loss:  0.165570
# Train Epoch : 49 [10/295]	Loss:  0.656025
# Train Epoch : 49 [20/295]	Loss:  1.139252
# Train Epoch : 49 [30/295]	Loss:  0.079841
# Train Epoch : 49 [40/295]	Loss:  0.816606
# Train Epoch : 49 [50/295]	Loss:  0.206201
# Train Epoch : 49 [60/295]	Loss:  0.862174
# Train Epoch : 49 [70/295]	Loss:  0.339224
# Train Epoch : 49 [80/295]	Loss:  0.884992
# Train Epoch : 49 [90/295]	Loss:  0.419597
# Train Epoch : 49 [100/295]	Loss:  0.541616
# Train Epoch : 49 [110/295]	Loss:  0.054660
# Train Epoch : 49 [120/295]	Loss:  0.316562
# Train Epoch : 49 [130/295]	Loss:  0.205454
# Train Epoch : 49 [140/295]	Loss:  0.091008
# Train Epoch : 49 [150/295]	Loss:  0.494263
# Train Epoch : 49 [160/295]	Loss:  0.580860
# Train Epoch : 49 [170/295]	Loss:  0.967908
# Train Epoch : 49 [180/295]	Loss:  0.858785
# Train Epoch : 49 [190/295]	Loss:  0.440407
# Train Epoch : 49 [200/295]	Loss:  1.023882
# Train Epoch : 49 [210/295]	Loss:  0.095589
# Train Epoch : 49 [220/295]	Loss:  0.293533
# Train Epoch : 49 [230/295]	Loss:  0.902147
# Train Epoch : 49 [240/295]	Loss:  0.004432
# Train Epoch : 49 [250/295]	Loss:  0.329678
# Train Epoch : 49 [260/295]	Loss:  0.263538
# Train Epoch : 49 [270/295]	Loss:  0.641905
# Train Epoch : 49 [280/295]	Loss:  0.920237
# Train Epoch : 49 [290/295]	Loss:  0.066964
# [FINAL] EfficientNet_V2_M Test Loss: 0.9284, Accuracy: 85.9060
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>best_val_accuracy</td><td>▁▄▅▆▆▇▇▇▇▇▇█████████████████████████████</td></tr><tr><td>epoch</td><td>▁▁▁▁▁▁▂▂▂▂▂▂▃▃▃▃▃▄▄▄▄▄▅▅▅▆▆▆▆▆▇▇▇▇▇█████</td></tr><tr><td>test_accuracy</td><td>▁</td></tr><tr><td>test_loss</td><td>▁</td></tr><tr><td>train_loss</td><td>█▄▃▄▃▃▃▃▂▂▂▂▁▂▂▄▃▂▂▃▄▁▁▂▁▃▂▃▃▁▄▁▂▂▂▂▃▂▂▄</td></tr><tr><td>val_accuracy</td><td>▁▄▆▆▇▇▆▇▇▇▇█▇▇▇█▇▇███▇▇▇▇██▇█▇▇██▇▇███▇█</td></tr><tr><td>val_loss</td><td>▅▃▂▂▁▃▃▃▃▃▄▄▃▂▂▂▃▃▃▂▄▅▅▅▄▃▃▅▄▆▅▄▄█▆██▆▇▆</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>best_val_accuracy</td><td>87.5</td></tr><tr><td>epoch</td><td>49</td></tr><tr><td>test_accuracy</td><td>85.90604</td></tr><tr><td>test_loss</td><td>0.92836</td></tr><tr><td>train_loss</td><td>0.06696</td></tr><tr><td>val_accuracy</td><td>85.90604</td></tr><tr><td>val_loss</td><td>0.92836</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">sweet-sweep-3</strong> at: <a href='https://wandb.ai/empe8339-gachon-university/model-comparison/runs/3cs7hnxi' target="_blank">https://wandb.ai/empe8339-gachon-university/model-comparison/runs/3cs7hnxi</a><br/> View project at: <a href='https://wandb.ai/empe8339-gachon-university/model-comparison' target="_blank">https://wandb.ai/empe8339-gachon-university/model-comparison</a><br/>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20241029_154532-3cs7hnxi/logs</code>
# wandb: Agent Starting Run: mdc0ntqs with config:
# wandb: 	batch_size: 16
# wandb: 	epochs: 50
# wandb: 	learning_rate: 0.01
# wandb: 	model_name: ResNet50
# wandb: 	optimizer: sgd
# Tracking run with wandb version 0.18.5
# Run data is saved locally in <code>/home/jovyan/wandb/run-20241029_170812-mdc0ntqs</code>
# Syncing run <strong><a href='https://wandb.ai/empe8339-gachon-university/model-comparison/runs/mdc0ntqs' target="_blank">gentle-sweep-4</a></strong> to <a href='https://wandb.ai/empe8339-gachon-university/model-comparison' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>Sweep page: <a href='https://wandb.ai/empe8339-gachon-university/model-comparison/sweeps/0zankx6a' target="_blank">https://wandb.ai/empe8339-gachon-university/model-comparison/sweeps/0zankx6a</a>
#  View project at <a href='https://wandb.ai/empe8339-gachon-university/model-comparison' target="_blank">https://wandb.ai/empe8339-gachon-university/model-comparison</a>
#  View sweep at <a href='https://wandb.ai/empe8339-gachon-university/model-comparison/sweeps/0zankx6a' target="_blank">https://wandb.ai/empe8339-gachon-university/model-comparison/sweeps/0zankx6a</a>
#  View run at <a href='https://wandb.ai/empe8339-gachon-university/model-comparison/runs/mdc0ntqs' target="_blank">https://wandb.ai/empe8339-gachon-university/model-comparison/runs/mdc0ntqs</a>
# /opt/conda/lib/python3.8/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet50_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet50_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Train Epoch : 0 [0/295]	Loss:  3.930355
# Train Epoch : 0 [10/295]	Loss:  3.887401
# Train Epoch : 0 [20/295]	Loss:  3.804026
# Train Epoch : 0 [30/295]	Loss:  3.967600
# Train Epoch : 0 [40/295]	Loss:  3.807794
# Train Epoch : 0 [50/295]	Loss:  3.663207
# Train Epoch : 0 [60/295]	Loss:  3.787141
# Train Epoch : 0 [70/295]	Loss:  3.691552
# Train Epoch : 0 [80/295]	Loss:  3.843582
# Train Epoch : 0 [90/295]	Loss:  3.806699
# Train Epoch : 0 [100/295]	Loss:  3.668495
# Train Epoch : 0 [110/295]	Loss:  3.655534
# Train Epoch : 0 [120/295]	Loss:  3.664947
# Train Epoch : 0 [130/295]	Loss:  3.561403
# Train Epoch : 0 [140/295]	Loss:  3.549510
# Train Epoch : 0 [150/295]	Loss:  3.554608
# Train Epoch : 0 [160/295]	Loss:  3.489847
# Train Epoch : 0 [170/295]	Loss:  3.277572
# Train Epoch : 0 [180/295]	Loss:  3.307745
# Train Epoch : 0 [190/295]	Loss:  3.604547
# Train Epoch : 0 [200/295]	Loss:  3.572108
# Train Epoch : 0 [210/295]	Loss:  3.436195
# Train Epoch : 0 [220/295]	Loss:  3.180489
# Train Epoch : 0 [230/295]	Loss:  3.296252
# Train Epoch : 0 [240/295]	Loss:  3.428529
# Train Epoch : 0 [250/295]	Loss:  2.808316
# Train Epoch : 0 [260/295]	Loss:  3.376609
# Train Epoch : 0 [270/295]	Loss:  3.329769
# Train Epoch : 0 [280/295]	Loss:  2.992060
# Train Epoch : 0 [290/295]	Loss:  3.220821
# Best model saved for ResNet50 with accuracy: 34.1216
# Train Epoch : 1 [0/295]	Loss:  3.562598
# Train Epoch : 1 [10/295]	Loss:  3.155247
# Train Epoch : 1 [20/295]	Loss:  3.429442
# Train Epoch : 1 [30/295]	Loss:  2.976698
# Train Epoch : 1 [40/295]	Loss:  2.906833
# Train Epoch : 1 [50/295]	Loss:  2.968452
# Train Epoch : 1 [60/295]	Loss:  3.254419
# Train Epoch : 1 [70/295]	Loss:  3.164559
# Train Epoch : 1 [80/295]	Loss:  3.323064
# Train Epoch : 1 [90/295]	Loss:  2.766537
# Train Epoch : 1 [100/295]	Loss:  3.360450
# Train Epoch : 1 [110/295]	Loss:  3.158559
# Train Epoch : 1 [120/295]	Loss:  2.884762
# Train Epoch : 1 [130/295]	Loss:  2.685024
# Train Epoch : 1 [140/295]	Loss:  2.976571
# Train Epoch : 1 [150/295]	Loss:  2.967114
# Train Epoch : 1 [160/295]	Loss:  3.000742
# Train Epoch : 1 [170/295]	Loss:  3.013782
